# %%
import googlemaps
import networkx as nx
import folium
from folium import plugins
import numpy as np
import matplotlib.pyplot as plt
from math import sin, cos, sqrt, atan2, radians
import pandas as pd
import requests
import pickle

# %%
class NoName:
    """
    1. Receive the shortest distance by receiving the source and target
    2. Receive point value or derive route information around it
    3. Derivation of slope by receiving source and target
    """
    
    def __init__(self,source,target):
        assert type(source) is str or tuple, 'source type must be location name or lonlat'
        assert type(target) is str or tuple, 'target type must be location name or lonlat'
        
        self.source = source
        self.target = target
        
        self.walk_speed = 0.058333 #km/min, 3.5km/h
        self.mobility_speed = self.walk_speed * 6 #20km/h
        #self.gmaps_key = "AIzaSyAk2xO72oiQS8zIi-E9YRp8-KxR4kdOtvg" #재관키
        self.gmaps_key = "AIzaSyA6GuIxbF0v51nl8ozexBmrPyiC5dUhcFA" #남식이형키
        self.gmaps = googlemaps.Client(key=self.gmaps_key)
        self.G = nx.read_gpickle('incheon_network_with_slope_final.gpickle') #도로네트워크
        self.G_bus = nx.read_gpickle('bus_with_density_final.gpickle') #버스네트워크
        self.G_subway = nx.read_gpickle('subway_with_density_time_final.gpickle') #지하철네트워크
        self.bike_list = pickle.load(open('bike.txt','rb')) #자전거 놓여있는 가상위치
        self.ODsay_KEY = 'rCBmn0ji2okFKgwtZWAfEH/IUEXDZaLU5Ue0oJoAgEs' #오디세이남식이형 키
#         self.url = f"https://api.odsay.com/v1/api/searchPubTransPath?SX={self.source[1]}&SY={self.source[0]}&EX={self.target[1]}&EY={self.target[0]}&apiKey={self.ODsay_KEY}"
#         self.data = requests.get(self.url).json()
        
        if type(source)==str:self.source=self.get_geocode(source)
        if type(target)==str:self.target=self.get_geocode(target)
#        if point == None:self.point = source
            
    def get_nearest_node(self,G_,point):
        """
        input :: graph to find nearest node(nx.Digraph), place geocode (tuple)
        output :: road nearest to the point (source_id,target_id)
        """
        
        nodes = G_.nodes
        srt_node_dist = 9999
        for node in nodes:
            
            dist = self.distance(point,G_.nodes[node]['lonlat'])
            if dist<srt_node_dist:
                srt_node_dist = dist
                srt_node = node
        return srt_node
    
    def get_nearest_link(self,G_,point):
        """
        input :: graph to find nearest node(nx.Digraph), place geocode (tuple)
        output :: road nearest to the point (source_id,target_id)
        """
        
        links = G_.edges
        srt_link_dist = 9999
        for source,target in links:
            middle_point = tuple((x+y)/2 for x,y in zip(G_.nodes[source]['lonlat'],G_.nodes[target]['lonlat']))
            dist = self.distance(point,middle_point)
            if dist<srt_link_dist:
                srt_link_dist = dist
                srt_link = source,target
        return srt_link
    
    def get_srt_path(self,G_,source,target):
        """
        input :: source geocode(tuple), target geocode(tuple)
        output :: shortest path (list of nodes), path dist (float)
        """
        
        source_ = self.get_nearest_link(G_,source)[0] #first node of the nearest link from source
        target_ = self.get_nearest_link(G_,target)[1] #second node of the nearest link from target

        path = nx.shortest_path(self.G,source_,target_,weight="distance")
        dist = nx.shortest_path_length(self.G,source_,target_,weight="distance")

        return path,dist
    
        
    
    def get_geocode(self,place):
        """
        input :: place name (str)
        output :: place geocode (tuple)
        """
        
        gmaps = googlemaps.Client(key=self.gmaps_key)
        result = gmaps.geocode(place)
        lat = result[0]['geometry']['location']['lat']
        lon = result[0]['geometry']['location']['lng']
        return lat,lon
    
        
    def distance(self,start,end):
        """
        input :: start geocode(tuple), end geocode(tuple)
        output :: distance between start and end (float, km)
        """
        
        R = 6373.0


        start_ = start
        end_ = end
        lat1 = radians(start_[0])
        lon1 = radians(start_[1])
        lat2 = radians(end_[0])
        lon2 = radians(end_[1])

        dlon = lon2 - lon1
        dlat = lat2 - lat1

        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))

        distance = R * c
        return distance

    def get_json_data(self):
        """
        get json data from odsay api
        input :: None
        output :: path data (json)
        
        https://lab.odsay.com/guide/releaseReference#searchPubTransPathT
        """
        url = f"https://api.odsay.com/v1/api/searchPubTransPath?SX={self.source[1]}&SY={self.source[0]}&EX={self.target[1]}&EY={self.target[0]}&apiKey={self.ODsay_KEY}"
        res = requests.get(url) # 이거 치면 API 호출된다. 조심하라. 하루 1,000개까지 무료로 사용 가능
        data = res.json() # 딕셔너리 형태로 가져오기
        return data
    

    def compare_time_density_by_making_dictionary(self,data):
        """
        make a dictionary of paths with time, density, max_slope, slope_list
        input :: path data (json)
        output :: result dictionary; path index as a key,
                                     time, density, max_slope, slope_list as values (dict),
                  path by walk from road network; path index as a key
                                                  list of nodes in path from road network as a value(dict)
        """
        result_final = {}
        walking_path_dict = {}
        
        for path in data['result']['path']:
            count=0
            index = data['result']['path'].index(path)
            result_final[index] = {}
            result_final[index]['api_time'] =  data['result']['path'][index]['info']['totalTime']
            total_time = 0
            
            for i,idx in enumerate(data['result']['path'][index]['subPath']):
                count +=1
                if idx['trafficType'] == 3: #도보
                    
                    if count == 1: #첫번째 경로는 무조건 도보라는 가정
                        
                        #첫번째 대중교통 정류장 시작점
                        start_station_lonlat = (data['result']['path'][index]['subPath'][i+1]['startY'],data['result']['path'][index]['subPath'][i+1]['startX'])
                        source_bike = self.check_if_bike_usage(start_station_lonlat,'source')
                        source_std_time = source_bike[1]
                        source_bike_spot = source_bike[0]

                        if idx['sectionTime'] <= source_std_time:
                            #자전거를 적어도 5분은 타자
                            total_time += idx['sectionTime']
                        elif self.distance(source_bike_spot,start_station_lonlat)/(self.mobility_speed) < 5:
                            total_time += idx['sectionTime']
                        else:
                            total_time += source_std_time
                    elif count==len(data['result']['path'][index]['subPath']): # 마지막 경로는 무조건 도보라는 가정
                        
                        #마지막 전 대중교통 정류장 도착점
                        end_station_lonlat = (data['result']['path'][index]['subPath'][i-1]['endY'],data['result']['path'][index]['subPath'][i-1]['endX'])
                        target_bike = self.check_if_bike_usage(end_station_lonlat,'target')
                        target_std_time = target_bike[1]
                        target_bike_spot = target_bike[0]

                        if idx['sectionTime'] <= target_std_time:
                            total_time += idx['sectionTime']
                        elif self.distance(target_bike_spot,end_station_lonlat)/(self.mobility_speed) < 5: 
                            #자전거를 적어도 5분은 타자
                            total_time += idx['sectionTime']
                        else:
                            total_time += target_std_time
                    else:
                        total_time += idx['sectionTime']
                else: #도보가 아닐때
                    total_time += idx['sectionTime']

            result_final[index]['mobility_time'] = total_time
    
    
            #도보 경로와 그 경사도 입력, 총 혼잡도(density) 계산
            walking_path_list = []
            density_weight = 0
            slope_list = []
            
            for index_temp,i in enumerate(path['subPath']):
                if i['trafficType'] == 3: #도보일때
                    
                    if index_temp == 0:
                        source_temp = self.source
                        target_temp = (path['subPath'][index_temp+1]['startY'],path['subPath'][index_temp+1]['startX'])
                    elif index_temp < len(path['subPath'])-1:
                        
                        source_temp = (path['subPath'][index_temp-1]['endY'],path['subPath'][index_temp-1]['endX'])
                        target_temp = (path['subPath'][index_temp+1]['startY'],path['subPath'][index_temp+1]['startX'])
                    else:
                        source_temp = (path['subPath'][index_temp-1]['endY'],path['subPath'][index_temp-1]['endX'])
                        target_temp = self.target
                    walk_path = self.get_srt_path(self.G,source_temp,target_temp)[0]
                    walking_path_list.append(walk_path)
                    #walk_path의 node들을 tuple로 연결 (1,2),(2,3),(3,4)
                    for idx in [tuple(pair) for pair in zip(walk_path[:-1], walk_path[1:])]:
                        slope_list.append(self.G.edges[idx]['interval_tan_max'])
                elif i['trafficType'] == 2: #버스
                    edge_list = []
                    start_lonlat = (i['startY'],i['startX'])
                    end_lonlat = (i['endY'],i['endX'])

                    #버그 발생 지점!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
                    start_node = self.get_nearest_node(self.G_bus,start_lonlat)
                    end_node = self.get_nearest_node(self.G_bus,end_lonlat)

                    bus_num = i['lane'][0]['busNo']
                    
                    #동일 경로 지나는 버스가 여러개일때 출력
                    if len(i['lane'])>1:
                        for idx in i['lane']:
                            print(str(index) + '번 째 경로에서 ' + idx['busNo'] + '도 가능합니다' )
                    
                    #버스 경로 직접 탐색
            
                    while True:
                        for idx in self.G_bus.out_edges(start_node):
                            #idx :: edges connected by start_node
                            if bus_num in self.G_bus.edges[idx]['route_num']:
                                edge_list.append(idx)
                                start_node = idx[1]

                        if end_node in edge_list[-1]:
                            break


                    density_list = []

                    for idx in edge_list:
                        #코드 돌리는 현재 시간으로 조회
                        #density_list.append(self.G_bus.edges[idx]['density_t'][i['lane'][0]['busNo']][int(time.strftime('%H'))][1])
                        
                        #16시 기준으로 조회
                        density_list.append(self.G_bus.edges[idx]['density_t'][i['lane'][0]['busNo']][16][1]) #16시
                        #['lane'] 에 버스 여러개 들어갈수도 있다
                    #평균혼잡도 * 이동시간
                    density_weight += i['sectionTime'] *sum(density_list)/len(density_list)


                elif i['trafficType'] ==1: #지하철
                    start_node = self.get_nearest_node(self.G_subway,(i['startY'],i['startX']))
                    end_node = self.get_nearest_node(self.G_subway,(i['endY'],i['endX']))
                    srt_path = nx.shortest_path(self.G_subway,start_node,end_node)


                    edge_list = [tuple(pair) for pair in zip(srt_path[:-1], srt_path[1:])] #경로에 포함되는 edge들
                    density_list = []
                    for idx in edge_list:
                        #density_list.append(self.G_subway.edges[idx]['density_t'][int(time.strftime('%H'))][1])
                        density_list.append(self.G_subway.edges[idx]['density_t'][16][1])
                        
                    #평균 혼잡도 * 이동시간    
                    density_weight += i['sectionTime'] * sum(density_list)/len(density_list)
                    
            result_final[index]['density_weight'] = density_weight
            result_final[index]['slope_max'] = max(slope_list)
            result_final[index]['slope_list'] = slope_list
            #index path의 도보 이동 경로들
            walking_path_dict[index] = walking_path_list
        return result_final,walking_path_dict
    
    def check_if_bike_usage(self,start_lonlat,source='source',std_time = 9999):
        """
        check if mobility should be used
        minimum of 5 minutes mobility usage
        
        input :: start geocode(tuple), source or target (string), default standard time (int)
        output :: geocode of the used mobility(tuple), total time(float)
        """
        #source일땐 도보로 모빌리티 타고 정류장으로
        if source == 'source':
            for lonlat in self.bike_list:

                distance = self.distance(lonlat,self.source)
                mobility_time_tmp = distance/self.walk_speed + self.distance(lonlat,start_lonlat)/(self.mobility_speed)
                if mobility_time_tmp < std_time:
                    std_time = mobility_time_tmp
                    bike_spot = lonlat
                    
            return bike_spot, std_time
        #target일때는 도보로 모빌리티 타고 target으로
        elif source == 'target':
            for lonlat in self.bike_list:

                distance = self.distance(lonlat,self.target)
                mobility_time_tmp = distance/(self.mobility_speed) + self.distance(lonlat,start_lonlat)/(self.walk_speed)
                if mobility_time_tmp < std_time:
                    std_time = mobility_time_tmp
                    bike_spot = lonlat
            return bike_spot, std_time


    def show_map_result_ODsay(self,data, weight = 'time',mapping = True):
        """
        get path graphic data from ODsay and draw on the map
        input :: data from ODsay (json), weight (sorting criteria - time, density, index(int)) (string or int), mapping (boolean)
        output :: folium map drawn with ODsay data (mapping = True),
                  result of path sorted by weight including time, density, and slope(dict)
                  path data from ODsay(json) (mapping = False)
        """
        
        result_final, walking_path_dict = self.compare_time_density_by_making_dictionary(data)
        #result_final = self.compare_time_density_by_making_dictionary(data)[0]
        #walking_path_dict = self.compare_time_density_by_making_dictionary(data)[1]
        sorted_paths = []
        source = self.source
        target = self.target

    
        if weight == 'time':
            for dictionary in result_final.values():
                sorted_paths.append(dictionary['mobility_time'])
            index_path = sorted_paths.index(min(sorted_paths))
        elif weight == 'density':
            for dictionary in result_final.values():
                sorted_paths.append(dictionary['density_weight'])
            index_path = sorted_paths.index(min(sorted_paths))
        else:
            index_path = int(weight)
        result_dict = result_final[index_path]
        final_path = data['result']['path'][index_path]
    
        if mapping:
            #loading path graphic data
            graphic_code = final_path['info']['mapObj']
            url2 = f"https://api.odsay.com/v1/api/loadLane?lang=0&mapObject=0:0@{graphic_code}&apiKey={self.ODsay_KEY}"
            res2 = requests.get(url2)
            data2 = res2.json()
            ex_map = folium.Map(location=source,zoom_start= 12,tiles = 'cartodbpositron')
            folium.Marker(location=source,
                          icon=folium.Icon(color='red',icon='home')
                         ).add_to(ex_map)
            folium.Marker(location=target,
                          icon=folium.Icon(color='red',icon='star')
                         ).add_to(ex_map)

            #make walking list by comparing api_time and mobility_time
            if result_dict['api_time'] > result_dict['mobility_time']:
                walking_list = walking_path_dict[index_path][1:-1]
                start_station_lonlat = (self.G.nodes[walking_path_dict[index_path][0][-1]]['lonlat'])

                source_bike_spot = self.check_if_bike_usage(start_station_lonlat,'source')[0]


                folium.PolyLine(locations = [self.source,source_bike_spot],color= 'green',line_width = 18).add_to(ex_map)
                folium.PolyLine(locations = [source_bike_spot,self.G.nodes[walking_path_dict[index_path][0][-1]]['lonlat']],color = 'grey').add_to(ex_map)

                end_station_lonlat = self.G.nodes[walking_path_dict[index_path][-1][0]]['lonlat']
                end_bike_spot = self.check_if_bike_usage(end_station_lonlat,'target')[0]


                folium.PolyLine(locations = [end_bike_spot,self.target],color= 'grey').add_to(ex_map)
                folium.PolyLine(locations = [end_bike_spot,self.G.nodes[walking_path_dict[index_path][-1][0]]['lonlat']],color = 'green').add_to(ex_map)

            else:
                walking_list = walking_path_dict[index_path]

            #draw walking path
            for idx in walking_list:
                lonlat_list = [self.G.nodes[node]['lonlat'] for node in idx]
                folium.PolyLine(locations = lonlat_list,color = 'green', line_width = 18).add_to(ex_map)
            
            #draw transportation path
            for idx in data2['result']['lane']:
                lonlat_list = []
                count = 0
                for i in idx['section']:

                    for lonlat_dict in i['graphPos']:
                        count +=1
                        #transfer point
                        if count == 1 or count == len(i['graphPos']):
                            folium.CircleMarker(location = (lonlat_dict['y'],lonlat_dict['x']),
                                          radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
                                         ).add_to(ex_map)
                        lonlat_list.append((lonlat_dict['y'],lonlat_dict['x']))
                        if idx['class'] == 1:#버스
                            folium.PolyLine(lonlat_list,color = 'blue',line_width = 18).add_to(ex_map)
                        elif idx['class'] ==2:#지하철
                            folium.PolyLine(lonlat_list,color = 'red',line_width = 18).add_to(ex_map)
            return ex_map
        else:
            return result_dict, final_path                            
    
    def show_map_result_my_network(self,data, weight = 'time',mapping = True):
        """
        get path graphic data from the network and draw on the map
        input :: data from ODsay (json), weight (sorting criteria - time, density, index(int)) (string or int), mapping (boolean)
        output :: folium map drawn with the network data (mapping = True),
                  result of path sorted by weight including time, density, and slope(dict)
                  path data from the network(json) (mapping = False)
        """
        
        result_final, walking_path_dict = self.compare_time_density_by_making_dictionary(data)
        #result_final = self.compare_time_density_by_making_dictionary(data)[0]
        #walking_path_dict = self.compare_time_density_by_making_dictionary(data)[1]
        sorted_paths = []
        source = self.source
        target = self.target


        if weight == 'time':
            for dictionary in result_final.values():
                sorted_paths.append(dictionary['mobility_time'])
            index_path = sorted_paths.index(min(sorted_paths))
        elif weight == 'density':
            for dictionary in result_final.values():
                sorted_paths.append(dictionary['density_weight'])
            index_path = sorted_paths.index(min(sorted_paths))
        else:
            index_path = int(weight)

        result_dict = result_final[index_path]
        final_path = data['result']['path'][index_path]
                    
            
        if mapping == True:

            ex_map = folium.Map(location=source,zoom_start= 12,tiles = 'cartodbpositron')
            folium.Marker(location=source,
                          icon=folium.Icon(color='red',icon='home')
                         ).add_to(ex_map)
            folium.Marker(location=target,
                          icon=folium.Icon(color='red',icon='star')
                         ).add_to(ex_map)


            #make walking list by comparing api_time and mobility_time
            if result_dict['api_time'] > result_dict['mobility_time']:
                #walk excluding first and last path
                walking_list = walking_path_dict[index_path][1:-1]
                #mobility usage at source
                start_station_lonlat = (self.G.nodes[walking_path_dict[index_path][0][-1]]['lonlat'])
                source_bike_spot = self.check_if_bike_usage(start_station_lonlat,'source')[0]

                folium.PolyLine(locations = [self.source,source_bike_spot],color= 'green').add_to(ex_map)
                folium.PolyLine(locations = [source_bike_spot,self.G.nodes[walking_path_dict[index_path][0][-1]]['lonlat']],color = 'grey').add_to(ex_map)
                #mobility usage at target
                end_station_lonlat = self.G.nodes[walking_path_dict[index_path][-1][0]]['lonlat']
                end_bike_spot = self.check_if_bike_usage(end_station_lonlat,'target')[0]

                folium.PolyLine(locations = [end_bike_spot,self.target],color= 'grey').add_to(ex_map)
                folium.PolyLine(locations = [end_bike_spot,self.G.nodes[walking_path_dict[index_path][-1][0]]['lonlat']],color = 'green').add_to(ex_map)

            else:
                walking_list = walking_path_dict[index_path]
            #draw walking path
            for idx in walking_list:
                lonlat_list = [self.G.nodes[node]['lonlat'] for node in idx]
                folium.PolyLine(locations = lonlat_list,color = 'green').add_to(ex_map)

                
                
            for i in final_path['subPath']:
                #path using bus
                if i['trafficType'] == 2: #버스
                    edge_list = []
                    start_lonlat = (i['startY'],i['startX'])
                    end_lonlat = (i['endY'],i['endX'])
                #에러 발생하는 부분!!!!!!!
                    start_node = self.get_nearest_node(self.G_bus,start_lonlat)
                    end_node = self.get_nearest_node(self.G_bus,end_lonlat)

                #transfer point
                    folium.CircleMarker(location = start_lonlat,
                                  radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
                                 ).add_to(ex_map)
                    folium.CircleMarker(location = end_lonlat,
                                  radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
                                 ).add_to(ex_map)

                    bus_num = i['lane'][0]['busNo']
                #find path using bus from the start_node to end_node
                    while True:
                        for idx in self.G_bus.out_edges(start_node):
                            if bus_num in self.G_bus.edges[idx]['route_num']:
                                edge_list.append(idx)
                                start_node = idx[1]

                        if end_node in edge_list[-1]:
                            break
                #drawing the path
                    for idx in range(len(edge_list)):
                        folium.PolyLine(locations=[self.G_bus.nodes[edge_list[idx][0]]['lonlat'],self.G_bus.nodes[edge_list[idx][1]]['lonlat']],
                                        color = "blue").add_to(ex_map)
                #path using subway
                elif i['trafficType'] ==1: #지하철
                    start_lonlat = (i['startY'],i['startX'])
                    end_lonlat = (i['endY'],i['endX'])

                    start_node = self.get_nearest_node(self.G_subway,start_lonlat)
                    end_node = self.get_nearest_node(self.G_subway,end_lonlat)
                    
                    #list of edges
                    srt_path = nx.shortest_path(self.G_subway,start_node,end_node)
                    
                    #drawing the path
                    folium.CircleMarker(location = start_lonlat,
                                  radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
                                 ).add_to(ex_map)
                    folium.CircleMarker(location = end_lonlat,
                                  radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
                                 ).add_to(ex_map)

                    for i in range(len(srt_path)-1):
                        folium.PolyLine(locations=[self.G_subway.nodes[srt_path[i]]['lonlat'],self.G_subway.nodes[srt_path[i+1]]['lonlat']],
                                        color = "red",line_width = 18).add_to(ex_map)





            return ex_map
        else:#mapping = False
            return result_dict, final_path
    
    
#         elif weight == 'time':
#             for dictionary in  result_final.values():
#                 sorted_paths.append(dictionary['mobility_time'])
#             result_dict = result_final[sorted_paths.index(min(sorted_paths))]
#             final_path = data['result']['path'][sorted_paths.index(min(sorted_paths))]
            
#             if mapping == True:
#                 source_loc = self.get_nearest_node(self.G_bus,source)
#                 target_loc = self.get_nearest_node(self.G_bus,target)
#                 ex_map = folium.Map(location=source,zoom_start= 12,tiles = 'cartodbpositron')
#                 folium.Marker(location=source,
#                               icon=folium.Icon(color='red',icon='home')
#                              ).add_to(ex_map)
#                 folium.Marker(location=target,
#                               icon=folium.Icon(color='red',icon='star')
#                              ).add_to(ex_map)
                
#                 if result_dict['api_time'] > result_dict['mobility_time']:
#                     walking_list = walking_path_dict[sorted_paths.index(min(sorted_paths))][1:-1]
#                     start_station_lonlat = (self.G.nodes[walking_path_dict[sorted_paths.index(min(sorted_paths))][0][-1]]['lonlat'])
                    
#                     source_bike_spot = self.check_if_bike_usage(start_station_lonlat,'source')[0]
                    

#                     folium.PolyLine(locations = [self.source,source_bike_spot],color= 'green').add_to(ex_map)
#                     folium.PolyLine(locations = [source_bike_spot,self.G.nodes[walking_path_dict[sorted_paths.index(min(sorted_paths))][0][-1]]['lonlat']],color = 'grey').add_to(ex_map)
                    
#                     end_station_lonlat = self.G.nodes[walking_path_dict[sorted_paths.index(min(sorted_paths))][-1][0]]['lonlat']
#                     end_bike_spot = self.check_if_bike_usage(end_station_lonlat,'target')[0]

                    
#                     folium.PolyLine(locations = [end_bike_spot,self.target],color= 'grey').add_to(ex_map)
#                     folium.PolyLine(locations = [end_bike_spot,self.G.nodes[walking_path_dict[sorted_paths.index(min(sorted_paths))][-1][0]]['lonlat']],color = 'green').add_to(ex_map)

#                 else:
#                     walking_list = walking_path_dict[sorted_paths.index(min(sorted_paths))]
                    
                    
                    
#                 for idx in walking_list:
#                     lonlat_list = [self.G.nodes[node]['lonlat'] for node in idx]
#                     folium.PolyLine(locations = lonlat_list,color = 'green').add_to(ex_map)


#                 for i in final_path['subPath']:

#                     if i['trafficType'] == 2: #버스
#                         edge_list = []
#                         start_lonlat = (i['startY'],i['startX'])
#                         end_lonlat = (i['endY'],i['endX'])

#                         start_node = self.get_nearest_node(self.G_bus,start_lonlat)
#                         end_node = self.get_nearest_node(self.G_bus,end_lonlat)
#                         folium.CircleMarker(location = start_lonlat,
#                                       radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
#                                      ).add_to(ex_map)
#                         folium.CircleMarker(location = end_lonlat,
#                                       radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
#                                      ).add_to(ex_map)

#                         bus_num = i['lane'][0]['busNo']

#                         while True:
#                             for idx in self.G_bus.out_edges(start_node):
#                                 if bus_num in self.G_bus.edges[idx]['route_num']:
#                                     edge_list.append(idx)
#                                     start_node = idx[1]

#                             if end_node in edge_list[-1]:
#                                 break

#                         for idx in range(len(edge_list)):
#                             folium.PolyLine(locations=[self.G_bus.nodes[edge_list[idx][0]]['lonlat'],self.G_bus.nodes[edge_list[idx][1]]['lonlat']],
#                                             color = "blue").add_to(ex_map)

#                     elif i['trafficType'] ==1: #지하철
#                         start_lonlat = (i['startY'],i['startX'])
#                         end_lonlat = (i['endY'],i['endX'])

#                         start_node = self.get_nearest_node(self.G_subway,start_lonlat)
#                         end_node = self.get_nearest_node(self.G_subway,end_lonlat)

#                         srt_path = nx.shortest_path(self.G_subway,start_node,end_node)
#                         folium.CircleMarker(location = start_lonlat,
#                                       radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
#                                      ).add_to(ex_map)
#                         folium.CircleMarker(location = end_lonlat,
#                                       radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
#                                      ).add_to(ex_map)

#                         for i in range(len(srt_path)-1):
#                             folium.PolyLine(locations=[self.G_subway.nodes[srt_path[i]]['lonlat'],self.G_subway.nodes[srt_path[i+1]]['lonlat']],
#                                             color = "red",line_width = 18).add_to(ex_map)
#                 return ex_map
#             return result_dict, final_path
                
#         else:
#             index_path = int(weight)
#             result_dict = result_final[index_path]
#             final_path = data['result']['path'][index_path]
            
#             if mapping == True:
#                 source_loc = self.get_nearest_node(self.G_bus,source)
#                 target_loc = self.get_nearest_node(self.G_bus,target)
#                 ex_map = folium.Map(location=source,zoom_start= 12,tiles = 'cartodbpositron')
#                 folium.Marker(location=source,
#                               icon=folium.Icon(color='red',icon='home')
#                              ).add_to(ex_map)
#                 folium.Marker(location=target,
#                               icon=folium.Icon(color='red',icon='star')
#                              ).add_to(ex_map)
                
#                 if result_dict['api_time'] > result_dict['mobility_time']:
#                     walking_list = walking_path_dict[index_path][1:-1]
#                     start_station_lonlat = (self.G.nodes[walking_path_dict[index_path][0][-1]]['lonlat'])
                    
#                     source_bike_spot = self.check_if_bike_usage(start_station_lonlat,'source')[0]
                    

#                     folium.PolyLine(locations = [self.source,source_bike_spot],color= 'green').add_to(ex_map)
#                     folium.PolyLine(locations = [source_bike_spot,self.G.nodes[walking_path_dict[index_path][0][-1]]['lonlat']],color = 'grey').add_to(ex_map)
                    
#                     end_station_lonlat = self.G.nodes[walking_path_dict[index_path][-1][0]]['lonlat']
#                     end_bike_spot = self.check_if_bike_usage(end_station_lonlat,'target')[0]

                    
#                     folium.PolyLine(locations = [end_bike_spot,self.target],color= 'grey').add_to(ex_map)
#                     folium.PolyLine(locations = [end_bike_spot,self.G.nodes[walking_path_dict[index_path][-1][0]]['lonlat']],color = 'green').add_to(ex_map)

#                 else:
#                     walking_list = walking_path_dict[index_path]
                    
                    
                    
#                 for idx in walking_list:
#                     lonlat_list = [self.G.nodes[node]['lonlat'] for node in idx]
#                     folium.PolyLine(locations = lonlat_list,color = 'green').add_to(ex_map)


#                 for i in final_path['subPath']:

#                     if i['trafficType'] == 2: #버스
#                         edge_list = []
#                         start_lonlat = (i['startY'],i['startX'])
#                         end_lonlat = (i['endY'],i['endX'])

#                         start_node = self.get_nearest_node(self.G_bus,start_lonlat)
#                         end_node = self.get_nearest_node(self.G_bus,end_lonlat)
#                         folium.CircleMarker(location = start_lonlat,
#                                       radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
#                                      ).add_to(ex_map)
#                         folium.CircleMarker(location = end_lonlat,
#                                       radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
#                                      ).add_to(ex_map)

#                         bus_num = i['lane'][0]['busNo']

#                         while True:
#                             for idx in self.G_bus.out_edges(start_node):
#                                 if bus_num in self.G_bus.edges[idx]['route_num']:
#                                     edge_list.append(idx)
#                                     start_node = idx[1]

#                             if end_node in edge_list[-1]:
#                                 break

#                         for idx in range(len(edge_list)):
#                             folium.PolyLine(locations=[self.G_bus.nodes[edge_list[idx][0]]['lonlat'],self.G_bus.nodes[edge_list[idx][1]]['lonlat']],
#                                             color = "blue",line_width = 18).add_to(ex_map)

#                     elif i['trafficType'] ==1: #지하철
#                         start_lonlat = (i['startY'],i['startX'])
#                         end_lonlat = (i['endY'],i['endX'])

#                         start_node = self.get_nearest_node(self.G_subway,start_lonlat)
#                         end_node = self.get_nearest_node(self.G_subway,end_lonlat)

#                         srt_path = nx.shortest_path(self.G_subway,start_node,end_node)
#                         folium.CircleMarker(location = start_lonlat,
#                                       radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
#                                      ).add_to(ex_map)
#                         folium.CircleMarker(location = end_lonlat,
#                                       radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
#                                      ).add_to(ex_map)

#                         for i in range(len(srt_path)-1):
#                             folium.PolyLine(locations=[self.G_subway.nodes[srt_path[i]]['lonlat'],self.G_subway.nodes[srt_path[i+1]]['lonlat']],
#                                             color = "red",line_width = 18).add_to(ex_map)


#                 return ex_map
#             return result_dict, final_path

    
    def add_multiple_map_by_index(self,data,weight = (0,1)):
        """
        add multiple paths using ODsay graphic data on the map
        input :: data from ODsay (json), tuple of indexes to add (tuple) (string or int)
        output :: folium map drawn with ODsay data 
        """
        
        result_final, walking_path_dict = self.compare_time_density_by_making_dictionary(data)
#         result_final = self.compare_time_density_by_making_dictionary(data)[0]
#         walking_path_dict = self.compare_time_density_by_making_dictionary(data)[1]
        sorted_paths = []
        source = self.source
        target = self.target
        #draw map with first index
        try:
            ex_map = self.show_map_result_ODsay(data,weight[0],mapping= True)
        #draw new map
        except:
            ex_map = folium.Map(location = source, zoom_start=12, tiles = 'cartodbpositron')
        folium.Marker(location=source,
                          icon=folium.Icon(color='red',icon='home')
                         ).add_to(ex_map)
        folium.Marker(location=target,
                          icon=folium.Icon(color='red',icon='star')
                         ).add_to(ex_map)

        for index in weight:
            
            index_path=int(index)
            result_dict = result_final[index_path]
            final_path = data['result']['path'][index_path]

            #loading path graphic data
            graphic_code = final_path['info']['mapObj']
            url2 = f"https://api.odsay.com/v1/api/loadLane?lang=0&mapObject=0:0@{graphic_code}&apiKey={self.ODsay_KEY}"
            res2 = requests.get(url2)
            data2 = res2.json()
            

            #make walking list by comparing api_time and mobility_time
            if result_dict['api_time'] > result_dict['mobility_time']:
                walking_list = walking_path_dict[index_path][1:-1]
                start_station_lonlat = (self.G.nodes[walking_path_dict[index_path][0][-1]]['lonlat'])

                source_bike_spot = self.check_if_bike_usage(start_station_lonlat,'source')[0]


                folium.PolyLine(locations = [self.source,source_bike_spot],color= 'green',line_width = 18).add_to(ex_map)
                folium.PolyLine(locations = [source_bike_spot,self.G.nodes[walking_path_dict[index_path][0][-1]]['lonlat']],color = 'grey').add_to(ex_map)

                end_station_lonlat = self.G.nodes[walking_path_dict[index_path][-1][0]]['lonlat']
                end_bike_spot = self.check_if_bike_usage(end_station_lonlat,'target')[0]


                folium.PolyLine(locations = [end_bike_spot,self.target],color= 'grey').add_to(ex_map)
                folium.PolyLine(locations = [end_bike_spot,self.G.nodes[walking_path_dict[index_path][-1][0]]['lonlat']],color = 'green').add_to(ex_map)

            else:
                walking_list = walking_path_dict[index_path]

            #draw walking path
            for idx in walking_list:
                lonlat_list = [self.G.nodes[node]['lonlat'] for node in idx]
                folium.PolyLine(locations = lonlat_list,color = 'green', line_width = 18).add_to(ex_map)
            
            #draw transportation path
            for idx in data2['result']['lane']:
                lonlat_list = []
                count = 0
                for i in idx['section']:

                    for lonlat_dict in i['graphPos']:
                        count +=1
                        #transfer point
                        if count == 1 or count == len(i['graphPos']):
                            folium.CircleMarker(location = (lonlat_dict['y'],lonlat_dict['x']),
                                          radius = 8, color = 'white',fill_color = 'black',fill_opacity=0.5
                                         ).add_to(ex_map)
                        lonlat_list.append((lonlat_dict['y'],lonlat_dict['x']))
                        if idx['class'] == 1:#버스
                            folium.PolyLine(lonlat_list,color = 'blue',line_width = 18).add_to(ex_map)
                        elif idx['class'] ==2:#지하철
                            folium.PolyLine(lonlat_list,color = 'red',line_width = 18).add_to(ex_map)
        return ex_map

# %%
#sample = NoName('주안역','인천대건고등학교')
sample = NoName('인하대학교','인천cgv')
#sample = NoName('인천cgv','선학초등학교')


#가장 가까운 버스정류장 찾을때 우리가 찾으려는 버스가 다니지 않는 정류장이 찾아지는 버그 존재  - compare_time_density_by_making_dictionary()

# %%
data = sample.get_json_data()

# %%
sample.compare_time_density_by_making_dictionary(data)
#data['result']['path'][7]
# Out:
# 3번 째 경로에서 8도 가능합니다
# 3번 째 경로에서 8A도 가능합니다
# 5번 째 경로에서 45도 가능합니다
# 5번 째 경로에서 42도 가능합니다
# 5번 째 경로에서 700-1도 가능합니다
# ({0: {'api_time': 35,
#    'mobility_time': 35,
#    'density_weight': 108.62192571940655,
#    'slope_max': 0.05466561559470895,
#    'slope_list': [0.03618729705408888,
#     0.012472670893877283,
#     0.05466561559470895,
#     0.022394983633299028,
#     0.0066849501374147465,
#     0.02427141387769785,
#     0.02011363066498013,
#     0.013507175135502019,
#     0.030325563592246044,
#     0.013127395044362616,
#     0.019093003651995198]},
#   1: {'api_time': 38,
#    'mobility_time': 38,
#    'density_weight': 106.9327816315768,
#    'slope_max': 0.03618729705408888,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.008391192084324492,
#     0.000293315127611501,
#     0.005019506741949448,
#     0.001424840393408202,
#     0.03444902701004066,
#     0.009501815911276874,
#     0.012588273407621682,
#     0.004096024486316605,
#     0.0017816400902651585,
#     0.03052177910523532,
#     0.03200728106291945,
#     0.00964539391266255,
#     0.034116660268844266]},
#   2: {'api_time': 38,
#    'mobility_time': 38,
#    'density_weight': 160.65697847838175,
#    'slope_max': 0.05082162624092295,
#    'slope_list': [0.03651945200560574,
#     0.01340131944172323,
#     0.034268335223975925,
#     0.026797054081993066,
#     0.036982861543852955,
#     0.013714955279385477,
#     0.02538118704005393,
#     0.05082162624092295,
#     0.02961846232394218]},
#   3: {'api_time': 39,
#    'mobility_time': 39,
#    'density_weight': 71.97474389536755,
#    'slope_max': 0.04162102220270396,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.008391192084324492,
#     0.000293315127611501,
#     0.005019506741949448,
#     0.001424840393408202,
#     0.0053541466148884906,
#     0.035748424465649464,
#     0.011324875883830385,
#     0.008686381040030586,
#     0.023912347932332302,
#     0.04162102220270396,
#     0.028513241988642125,
#     0.02961846232394218]},
#   4: {'api_time': 39,
#    'mobility_time': 39,
#    'density_weight': 180.66198485699067,
#    'slope_max': 0.0389475858803564,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.008391192084324492,
#     0.000293315127611501,
#     0.005019506741949448,
#     0.001424840393408202,
#     0.0036245534042773668,
#     0.007592784965754395,
#     0.006682401650633694,
#     0.01977352275904008,
#     0.004200757664444035,
#     0.017780310990200957,
#     0.0389475858803564,
#     0.00647325288928254,
#     0.0073383292679194785,
#     0.019093003651995198]},
#   5: {'api_time': 44,
#    'mobility_time': 44,
#    'density_weight': 183.4762860657777,
#    'slope_max': 0.03651945200560574,
#    'slope_list': [0.03651945200560574,
#     0.01340131944172323,
#     0.034268335223975925,
#     0.026797054081993066,
#     0.01182654417399869,
#     0.005118264639109166,
#     0.020124271092945515,
#     0.013507175135502019,
#     0.030325563592246044,
#     0.013127395044362616,
#     0.019093003651995198]},
#   6: {'api_time': 44,
#    'mobility_time': 41,
#    'density_weight': 167.74959677419352,
#    'slope_max': 0.0389475858803564,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.010163657920923053,
#     0.004588463855611397,
#     0.001218472226810441,
#     0.0389475858803564,
#     0.00647325288928254,
#     0.0073383292679194785,
#     0.019093003651995198]},
#   7: {'api_time': 47,
#    'mobility_time': 47,
#    'density_weight': 56.45001005480355,
#    'slope_max': 0.05466561559470895,
#    'slope_list': [0.03618729705408888,
#     0.012472670893877283,
#     0.05466561559470895,
#     0.022394983633299028,
#     0.0066849501374147465,
#     0.02427141387769785,
#     0.02011363066498013,
#     0.007436106204656805,
#     0.003586065111941183,
#     0.01796207525109752,
#     0.013507175135502019,
#     0.030325563592246044,
#     0.013127395044362616,
#     0.019093003651995198]},
#   8: {'api_time': 29,
#    'mobility_time': 29,
#    'density_weight': 25.357997647154274,
#    'slope_max': 0.04162102220270396,
#    'slope_list': [0.03651945200560574,
#     0.0053541466148884906,
#     0.035748424465649464,
#     0.011324875883830385,
#     0.008686381040030586,
#     0.023912347932332302,
#     0.04162102220270396,
#     0.028513241988642125,
#     0.02961846232394218]},
#   9: {'api_time': 48,
#    'mobility_time': 48,
#    'density_weight': 70.41278388235247,
#    'slope_max': 0.03618729705408888,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.0004201714094864368,
#     0.018880140812103513,
#     0.021710702061838227,
#     0.007084657185526609,
#     0.0053499709925117125,
#     0.01751993925479249,
#     0.030224518726606076,
#     0.028513241988642125,
#     0.02961846232394218]},
#   10: {'api_time': 40,
#    'mobility_time': 40,
#    'density_weight': 124.43049323393282,
#    'slope_max': 0.0389475858803564,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.008391192084324492,
#     0.000293315127611501,
#     0.005019506741949448,
#     0.001424840393408202,
#     0.0036245534042773668,
#     0.007592784965754395,
#     0.006682401650633694,
#     0.01977352275904008,
#     0.004200757664444035,
#     0.017780310990200957,
#     0.0389475858803564,
#     0.00647325288928254,
#     0.0073383292679194785,
#     0.019093003651995198]},
#   11: {'api_time': 39,
#    'mobility_time': 39,
#    'density_weight': 138.50936212381993,
#    'slope_max': 0.0389475858803564,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.008391192084324492,
#     0.000293315127611501,
#     0.005019506741949448,
#     0.001424840393408202,
#     0.0036410441914730236,
#     0.0389475858803564,
#     0.00647325288928254,
#     0.0073383292679194785,
#     0.019093003651995198]},
#   12: {'api_time': 44,
#    'mobility_time': 44,
#    'density_weight': 142.07050423917894,
#    'slope_max': 0.03618729705408888,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.008391192084324492,
#     0.000293315127611501,
#     0.005019506741949448,
#     0.001424840393408202,
#     0.031234553828617125,
#     0.03444902701004066,
#     0.009501815911276874,
#     0.012588273407621682,
#     0.004096024486316605,
#     0.0017816400902651585,
#     0.03052177910523532,
#     0.03200728106291945,
#     0.00964539391266255,
#     0.034116660268844266]},
#   13: {'api_time': 44,
#    'mobility_time': 44,
#    'density_weight': 139.77282868849133,
#    'slope_max': 0.03618729705408888,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.008391192084324492,
#     0.000293315127611501,
#     0.005019506741949448,
#     0.001424840393408202,
#     0.031234553828617125,
#     0.03444902701004066,
#     0.009501815911276874,
#     0.012588273407621682,
#     0.004096024486316605,
#     0.0017816400902651585,
#     0.03052177910523532,
#     0.03200728106291945,
#     0.00964539391266255,
#     0.034116660268844266]},
#   14: {'api_time': 46,
#    'mobility_time': 46,
#    'density_weight': 142.6808243073303,
#    'slope_max': 0.03618729705408888,
#    'slope_list': [0.03618729705408888,
#     0.03200821088661517,
#     0.004166016096444839,
#     0.0013014069617949173,
#     0.000459332655323604,
#     0.010529556552951284,
#     0.008391192084324492,
#     0.000293315127611501,
#     0.005019506741949448,
#     0.001424840393408202,
#     0.023314285750606328,
#     0.03444902701004066,
#     0.009501815911276874,
#     0.012588273407621682,
#     0.004096024486316605,
#     0.0017816400902651585,
#     0.03052177910523532,
#     0.03200728106291945,
#     0.00964539391266255,
#     0.034116660268844266]}},
#  {0: [['187623',
#     '187622',
#     '188061',
#     '632198',
#     '188064',
#     '187593',
#     '187696',
#     '189873'],
#    ['187728', '189583', '188548', '188547', '188549']],
#   1: [['187623',
#     '187622',
#     '604217',
#     '604219',
#     '604218',
#     '187638',
#     '188218',
#     '188217',
#     '551376',
#     '632943',
#     '632942'],
#    ['188134',
#     '188836',
#     '187806',
#     '189184',
#     '187781',
#     '189486',
#     '189485',
#     '188550',
#     '190336',
#     '188549']],
#   2: [['187623', '632189'],
#    ['187716', '187713', '187714', '190242'],
#    ['580783', '580784', '187691', '187732', '187704', '188549']],
#   3: [['187623',
#     '187622',
#     '604217',
#     '604219',
#     '604218',
#     '187638',
#     '188218',
#     '188217',
#     '551376',
#     '632943',
#     '632942'],
#    ['188690',
#     '189882',
#     '190553',
#     '190099',
#     '190101',
#     '190100',
#     '187703',
#     '187704',
#     '188549']],
#   4: [['187623',
#     '187622',
#     '604217',
#     '604219',
#     '604218',
#     '187638',
#     '188218',
#     '188217',
#     '551376',
#     '632943',
#     '632942'],
#    ['189608', '189610', '189895', '187727', '187733', '190244', '190881'],
#    ['187681', '187734', '189483', '188547', '188549']],
#   5: [['187623', '632189'],
#    ['187716', '187713', '187714', '190242'],
#    ['190284', '190337', '187807', '187993'],
#    ['187728', '189583', '188548', '188547', '188549']],
#   6: [['187623', '187622', '604217', '604219', '604218', '187638', '188218'],
#    ['185567', '580460', '184312', '551218'],
#    ['187681', '187734', '189483', '188547', '188549']],
#   7: [['187623',
#     '187622',
#     '188061',
#     '632198',
#     '188064',
#     '187593',
#     '187696',
#     '189873'],
#    ['187780',
#     '187813',
#     '190780',
#     '187728',
#     '189583',
#     '188548',
#     '188547',
#     '188549']],
#   8: [['187623', '632189'],
#    ['188690',
#     '189882',
#     '190553',
#     '190099',
#     '190101',
#     '190100',
#     '187703',
#     '187704',
#     '188549']],
#   9: [['187623', '187622', '604217', '604219', '604218', '187638', '188218'],
#    ['185567', '580456', '580458', '185252', '184261', '185359'],
#    ['187726', '188731', '187703', '187704', '188549']],
#   10: [['187623',
#     '187622',
#     '604217',
#     '604219',
#     '604218',
#     '187638',
#     '188218',
#     '188217',
#     '551376',
#     '632943',
#     '632942'],
#    ['189608', '189610', '189895', '187727', '187733', '190244', '190881'],
#    ['187681', '187734', '189483', '188547', '188549']],
#   11: [['187623',
#     '187622',
#     '604217',
#     '604219',
#     '604218',
#     '187638',
#     '188218',
#     '188217',
#     '551376',
#     '632943',
#     '632942'],
#    ['187686', '187689'],
#    ['187681', '187734', '189483', '188547', '188549']],
#   12: [['187623',
#     '187622',
#     '604217',
#     '604219',
#     '604218',
#     '187638',
#     '188218',
#     '188217',
#     '551376',
#     '632943',
#     '632942'],
#    ['189904', '189911'],
#    ['188134',
#     '188836',
#     '187806',
#     '189184',
#     '187781',
#     '189486',
#     '189485',
#     '188550',
#     '190336',
#     '188549']],
#   13: [['187623',
#     '187622',
#     '604217',
#     '604219',
#     '604218',
#     '187638',
#     '188218',
#     '188217',
#     '551376',
#     '632943',
#     '632942'],
#    ['189904', '189911'],
#    ['188134',
#     '188836',
#     '187806',
#     '189184',
#     '187781',
#     '189486',
#     '189485',
#     '188550',
#     '190336',
#     '188549']],
#   14: [['187623',
#     '187622',
#     '604217',
#     '604219',
#     '604218',
#     '187638',
#     '188218',
#     '188217',
#     '551376',
#     '632943',
#     '632942'],
#    ['189196', '580757'],
#    ['188134',
#     '188836',
#     '187806',
#     '189184',
#     '187781',
#     '189486',
#     '189485',
#     '188550',
#     '190336',
#     '188549']]})

# %%
m1 = sample.show_map_result_my_network(data,weight = 'density',mapping = True)
m1
# Out:
# 3번 째 경로에서 522도 가능합니다
# 3번 째 경로에서 522A도 가능합니다
# 4번 째 경로에서 523도 가능합니다
# 4번 째 경로에서 523-1도 가능합니다
# 9번 째 경로에서 45도 가능합니다
# 9번 째 경로에서 42도 가능합니다
# 9번 째 경로에서 700-1도 가능합니다
# 10번 째 경로에서 522도 가능합니다
# 10번 째 경로에서 522A도 가능합니다
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2 = sample.show_map_result_my_network(data,weight = 'time',mapping = True)
m2
# Out:
# 3번 째 경로에서 522도 가능합니다
# 3번 째 경로에서 522A도 가능합니다
# 4번 째 경로에서 523도 가능합니다
# 4번 째 경로에서 523-1도 가능합니다
# 9번 째 경로에서 45도 가능합니다
# 9번 째 경로에서 42도 가능합니다
# 9번 째 경로에서 700-1도 가능합니다
# 10번 째 경로에서 522도 가능합니다
# 10번 째 경로에서 522A도 가능합니다
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m3 = sample.show_map_result_my_network(data,weight = 6,mapping = True)
m3
# Out:
# 3번 째 경로에서 522도 가능합니다
# 3번 째 경로에서 522A도 가능합니다
# 4번 째 경로에서 523도 가능합니다
# 4번 째 경로에서 523-1도 가능합니다
# 9번 째 경로에서 45도 가능합니다
# 9번 째 경로에서 42도 가능합니다
# 9번 째 경로에서 700-1도 가능합니다
# 10번 째 경로에서 522도 가능합니다
# 10번 째 경로에서 522A도 가능합니다
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m4 = sample.show_map_result_ODsay(data,weight='density',mapping=True)
m4
# Out:
# 3번 째 경로에서 522도 가능합니다
# 3번 째 경로에서 522A도 가능합니다
# 4번 째 경로에서 523도 가능합니다
# 4번 째 경로에서 523-1도 가능합니다
# 9번 째 경로에서 45도 가능합니다
# 9번 째 경로에서 42도 가능합니다
# 9번 째 경로에서 700-1도 가능합니다
# 10번 째 경로에서 522도 가능합니다
# 10번 째 경로에서 522A도 가능합니다
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m5 = sample.show_map_result_ODsay(data,weight='time',mapping=True)
m5
# Out:
# 3번 째 경로에서 522도 가능합니다
# 3번 째 경로에서 522A도 가능합니다
# 4번 째 경로에서 523도 가능합니다
# 4번 째 경로에서 523-1도 가능합니다
# 9번 째 경로에서 45도 가능합니다
# 9번 째 경로에서 42도 가능합니다
# 9번 째 경로에서 700-1도 가능합니다
# 10번 째 경로에서 522도 가능합니다
# 10번 째 경로에서 522A도 가능합니다
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m6 = sample.show_map_result_ODsay(data,weight=6,mapping=True)

m5.add_to(m6)
# Out:
# 3번 째 경로에서 522도 가능합니다
# 3번 째 경로에서 522A도 가능합니다
# 4번 째 경로에서 523도 가능합니다
# 4번 째 경로에서 523-1도 가능합니다
# 9번 째 경로에서 45도 가능합니다
# 9번 째 경로에서 42도 가능합니다
# 9번 째 경로에서 700-1도 가능합니다
# 10번 째 경로에서 522도 가능합니다
# 10번 째 경로에서 522A도 가능합니다
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m7 = sample.add_multiple_map_by_index(data,weight = (2,4,6))
m7
# Out:
# 3번 째 경로에서 8도 가능합니다
# 3번 째 경로에서 8A도 가능합니다
# 5번 째 경로에서 45도 가능합니다
# 5번 째 경로에서 42도 가능합니다
# 5번 째 경로에서 700-1도 가능합니다
# 3번 째 경로에서 8도 가능합니다
# 3번 째 경로에서 8A도 가능합니다
# 5번 째 경로에서 45도 가능합니다
# 5번 째 경로에서 42도 가능합니다
# 5번 째 경로에서 700-1도 가능합니다
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests

# 출발 좌표 인하대후문
SX = sample.source[1]
SY = sample.source[0]

# 도착 좌표 백운역
EX = sample.target[1]
EY = sample.target[0]

# API 키 발급 받음 : 남식이형 아이디로 서버컴 IP 입력해서 받음.
KEY = 'rCBmn0ji2okFKgwtZWAfEH/IUEXDZaLU5Ue0oJoAgEs'

# ODsay에서 제공하는 url 사용
url = f"https://api.odsay.com/v1/api/searchPubTransPath?SX={SX}&SY={SY}&EX={EX}&EY={EY}&apiKey={KEY}"
url2 = f"https://api.odsay.com/v1/api/loadLane?lang=0&mapObject=0:0@21124:1:5:13@21153:1:68:79&apiKey={KEY}"
#이거는 노선 그래픽 api
#https://api.odsay.com/v1/api/loadLane?lang=0&mapObject=0:0@3:2:310:329

# %%
data = requests.get(url).json()
data
# Out:
# {'result': {'searchType': 0,
#   'outTrafficCheck': 1,
#   'busCount': 10,
#   'subwayCount': 1,
#   'subwayBusCount': 5,
#   'pointDistance': 9338,
#   'startRadius': 700,
#   'endRadius': 700,
#   'path': [{'pathType': 1,
#     'info': {'trafficDistance': 9900.0,
#      'totalWalk': 481,
#      'totalTime': 32,
#      'payment': 1250,
#      'busTransitCount': 0,
#      'subwayTransitCount': 1,
#      'mapObj': '20001:2:20124:20134',
#      'firstStartStation': '인천시청',
#      'lastEndStation': '테크노파크',
#      'totalStationCount': 10,
#      'busStationCount': 0,
#      'subwayStationCount': 10,
#      'totalDistance': 10381.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 368, 'sectionTime': 6},
#      {'trafficType': 1,
#       'distance': 9900,
#       'sectionTime': 24,
#       'stationCount': 10,
#       'lane': [{'name': '인천 1호선', 'subwayCode': 21, 'subwayCityCode': 2000}],
#       'startName': '인천시청',
#       'startX': 126.702217,
#       'startY': 37.457614,
#       'endName': '테크노파크',
#       'endX': 126.656407,
#       'endY': 37.382298,
#       'way': '테크노파크',
#       'wayCode': 2,
#       'door': 'null',
#       'startID': 20124,
#       'endID': 20134,
#       'startExitNo': '4',
#       'startExitX': 126.70289838913733,
#       'startExitY': 37.456640388104624,
#       'endExitNo': '2',
#       'endExitX': 126.65681598092114,
#       'endExitY': 37.38156412193719,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 20124,
#          'stationName': '인천시청',
#          'x': '126.70222',
#          'y': '37.457619'},
#         {'index': 1,
#          'stationID': 20125,
#          'stationName': '예술회관',
#          'x': '126.701016',
#          'y': '37.449312'},
#         {'index': 2,
#          'stationID': 20126,
#          'stationName': '인천터미널',
#          'x': '126.699664',
#          'y': '37.441857'},
#         {'index': 3,
#          'stationID': 20127,
#          'stationName': '문학경기장',
#          'x': '126.698344',
#          'y': '37.434959'},
#         {'index': 4,
#          'stationID': 20128,
#          'stationName': '선학',
#          'x': '126.69893',
#          'y': '37.426963'},
#         {'index': 5,
#          'stationID': 20129,
#          'stationName': '신연수',
#          'x': '126.694023',
#          'y': '37.418062'},
#         {'index': 6,
#          'stationID': 20130,
#          'stationName': '원인재',
#          'x': '126.687844',
#          'y': '37.412342'},
#         {'index': 7,
#          'stationID': 20131,
#          'stationName': '동춘',
#          'x': '126.680956',
#          'y': '37.404688'},
#         {'index': 8,
#          'stationID': 20132,
#          'stationName': '동막',
#          'x': '126.673606',
#          'y': '37.398135'},
#         {'index': 9,
#          'stationID': 20133,
#          'stationName': '캠퍼스타운',
#          'x': '126.662085',
#          'y': '37.388205'},
#         {'index': 10,
#          'stationID': 20134,
#          'stationName': '테크노파크',
#          'x': '126.656412',
#          'y': '37.382306'}]}},
#      {'trafficType': 3, 'distance': 113, 'sectionTime': 2}]},
#    {'pathType': 3,
#     'info': {'trafficDistance': 9859.0,
#      'totalWalk': 553,
#      'totalTime': 37,
#      'payment': 1250,
#      'busTransitCount': 1,
#      'subwayTransitCount': 1,
#      'mapObj': '21037:1:78:80@20001:2:20125:20134',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '테크노파크',
#      'totalStationCount': 11,
#      'busStationCount': 2,
#      'subwayStationCount': 9,
#      'totalDistance': 10412.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 959,
#       'sectionTime': 7,
#       'stationCount': 2,
#       'lane': [{'busNo': '45', 'type': 11, 'busID': 21037},
#        {'busNo': '42', 'type': 11, 'busID': 21035},
#        {'busNo': '700-1', 'type': 11, 'busID': 21203}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '시청광장입구',
#       'endX': 126.703227,
#       'endY': 37.450164,
#       'startID': 181144,
#       'endID': 181153,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181153,
#          'stationName': '시청광장입구',
#          'x': '126.703227',
#          'y': '37.450164'}]}},
#      {'trafficType': 3, 'distance': 217, 'sectionTime': 3},
#      {'trafficType': 1,
#       'distance': 8900,
#       'sectionTime': 22,
#       'stationCount': 9,
#       'lane': [{'name': '인천 1호선', 'subwayCode': 21, 'subwayCityCode': 2000}],
#       'startName': '예술회관',
#       'startX': 126.701016,
#       'startY': 37.449311,
#       'endName': '테크노파크',
#       'endX': 126.656407,
#       'endY': 37.382298,
#       'way': '테크노파크',
#       'wayCode': 2,
#       'door': 'null',
#       'startID': 20125,
#       'endID': 20134,
#       'startExitNo': '3',
#       'startExitX': 126.70162499811649,
#       'startExitY': 37.44992453039697,
#       'endExitNo': '2',
#       'endExitX': 126.65681598092114,
#       'endExitY': 37.38156412193719,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 20125,
#          'stationName': '예술회관',
#          'x': '126.701016',
#          'y': '37.449312'},
#         {'index': 1,
#          'stationID': 20126,
#          'stationName': '인천터미널',
#          'x': '126.699664',
#          'y': '37.441857'},
#         {'index': 2,
#          'stationID': 20127,
#          'stationName': '문학경기장',
#          'x': '126.698344',
#          'y': '37.434959'},
#         {'index': 3,
#          'stationID': 20128,
#          'stationName': '선학',
#          'x': '126.69893',
#          'y': '37.426963'},
#         {'index': 4,
#          'stationID': 20129,
#          'stationName': '신연수',
#          'x': '126.694023',
#          'y': '37.418062'},
#         {'index': 5,
#          'stationID': 20130,
#          'stationName': '원인재',
#          'x': '126.687844',
#          'y': '37.412342'},
#         {'index': 6,
#          'stationID': 20131,
#          'stationName': '동춘',
#          'x': '126.680956',
#          'y': '37.404688'},
#         {'index': 7,
#          'stationID': 20132,
#          'stationName': '동막',
#          'x': '126.673606',
#          'y': '37.398135'},
#         {'index': 8,
#          'stationID': 20133,
#          'stationName': '캠퍼스타운',
#          'x': '126.662085',
#          'y': '37.388205'},
#         {'index': 9,
#          'stationID': 20134,
#          'stationName': '테크노파크',
#          'x': '126.656412',
#          'y': '37.382306'}]}},
#      {'trafficType': 3, 'distance': 113, 'sectionTime': 2}]},
#    {'pathType': 3,
#     'info': {'trafficDistance': 9859.0,
#      'totalWalk': 553,
#      'totalTime': 38,
#      'payment': 1250,
#      'busTransitCount': 1,
#      'subwayTransitCount': 1,
#      'mapObj': '20001:2:20124:20132@21249:1:49:51',
#      'firstStartStation': '인천시청',
#      'lastEndStation': '테크노파크역',
#      'totalStationCount': 10,
#      'busStationCount': 2,
#      'subwayStationCount': 8,
#      'totalDistance': 10412.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 368, 'sectionTime': 6},
#      {'trafficType': 1,
#       'distance': 7500,
#       'sectionTime': 20,
#       'stationCount': 8,
#       'lane': [{'name': '인천 1호선', 'subwayCode': 21, 'subwayCityCode': 2000}],
#       'startName': '인천시청',
#       'startX': 126.702217,
#       'startY': 37.457614,
#       'endName': '동막',
#       'endX': 126.673596,
#       'endY': 37.398134,
#       'way': '동막',
#       'wayCode': 2,
#       'door': 'null',
#       'startID': 20124,
#       'endID': 20132,
#       'startExitNo': '4',
#       'startExitX': 126.70289838913733,
#       'startExitY': 37.456640388104624,
#       'endExitNo': '3',
#       'endExitX': 126.67269007196894,
#       'endExitY': 37.3981697532548,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 20124,
#          'stationName': '인천시청',
#          'x': '126.70222',
#          'y': '37.457619'},
#         {'index': 1,
#          'stationID': 20125,
#          'stationName': '예술회관',
#          'x': '126.701016',
#          'y': '37.449312'},
#         {'index': 2,
#          'stationID': 20126,
#          'stationName': '인천터미널',
#          'x': '126.699664',
#          'y': '37.441857'},
#         {'index': 3,
#          'stationID': 20127,
#          'stationName': '문학경기장',
#          'x': '126.698344',
#          'y': '37.434959'},
#         {'index': 4,
#          'stationID': 20128,
#          'stationName': '선학',
#          'x': '126.69893',
#          'y': '37.426963'},
#         {'index': 5,
#          'stationID': 20129,
#          'stationName': '신연수',
#          'x': '126.694023',
#          'y': '37.418062'},
#         {'index': 6,
#          'stationID': 20130,
#          'stationName': '원인재',
#          'x': '126.687844',
#          'y': '37.412342'},
#         {'index': 7,
#          'stationID': 20131,
#          'stationName': '동춘',
#          'x': '126.680956',
#          'y': '37.404688'},
#         {'index': 8,
#          'stationID': 20132,
#          'stationName': '동막',
#          'x': '126.673606',
#          'y': '37.398135'}]}},
#      {'trafficType': 3, 'distance': 77, 'sectionTime': 1},
#      {'trafficType': 2,
#       'distance': 2359,
#       'sectionTime': 9,
#       'stationCount': 2,
#       'lane': [{'busNo': '909', 'type': 26, 'busID': 21249}],
#       'startName': '동막역(3번출구)',
#       'startX': 126.672746,
#       'startY': 37.398287,
#       'endName': '테크노파크역',
#       'endX': 126.65601,
#       'endY': 37.381762,
#       'startID': 194779,
#       'endID': 193476,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'},
#         {'index': 1,
#          'stationID': 193477,
#          'stationName': '캠퍼스타운역',
#          'x': '126.661564',
#          'y': '37.387538'},
#         {'index': 2,
#          'stationID': 193476,
#          'stationName': '테크노파크역',
#          'x': '126.65601',
#          'y': '37.381762'}]}},
#      {'trafficType': 3, 'distance': 108, 'sectionTime': 2}]},
#    {'pathType': 3,
#     'info': {'trafficDistance': 9908.0,
#      'totalWalk': 563,
#      'totalTime': 39,
#      'payment': 1250,
#      'busTransitCount': 1,
#      'subwayTransitCount': 1,
#      'mapObj': '20001:2:20124:20133@21269:1:41:42',
#      'firstStartStation': '인천시청',
#      'lastEndStation': '테크노파크역',
#      'totalStationCount': 10,
#      'busStationCount': 1,
#      'subwayStationCount': 9,
#      'totalDistance': 10471.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 368, 'sectionTime': 6},
#      {'trafficType': 1,
#       'distance': 9100,
#       'sectionTime': 23,
#       'stationCount': 9,
#       'lane': [{'name': '인천 1호선', 'subwayCode': 21, 'subwayCityCode': 2000}],
#       'startName': '인천시청',
#       'startX': 126.702217,
#       'startY': 37.457614,
#       'endName': '캠퍼스타운',
#       'endX': 126.662083,
#       'endY': 37.388201,
#       'way': '캠퍼스타운',
#       'wayCode': 2,
#       'door': 'null',
#       'startID': 20124,
#       'endID': 20133,
#       'startExitNo': '4',
#       'startExitX': 126.70289838913733,
#       'startExitY': 37.456640388104624,
#       'endExitNo': '3',
#       'endExitX': 126.66147561494519,
#       'endExitY': 37.3879306235446,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 20124,
#          'stationName': '인천시청',
#          'x': '126.70222',
#          'y': '37.457619'},
#         {'index': 1,
#          'stationID': 20125,
#          'stationName': '예술회관',
#          'x': '126.701016',
#          'y': '37.449312'},
#         {'index': 2,
#          'stationID': 20126,
#          'stationName': '인천터미널',
#          'x': '126.699664',
#          'y': '37.441857'},
#         {'index': 3,
#          'stationID': 20127,
#          'stationName': '문학경기장',
#          'x': '126.698344',
#          'y': '37.434959'},
#         {'index': 4,
#          'stationID': 20128,
#          'stationName': '선학',
#          'x': '126.69893',
#          'y': '37.426963'},
#         {'index': 5,
#          'stationID': 20129,
#          'stationName': '신연수',
#          'x': '126.694023',
#          'y': '37.418062'},
#         {'index': 6,
#          'stationID': 20130,
#          'stationName': '원인재',
#          'x': '126.687844',
#          'y': '37.412342'},
#         {'index': 7,
#          'stationID': 20131,
#          'stationName': '동춘',
#          'x': '126.680956',
#          'y': '37.404688'},
#         {'index': 8,
#          'stationID': 20132,
#          'stationName': '동막',
#          'x': '126.673606',
#          'y': '37.398135'},
#         {'index': 9,
#          'stationID': 20133,
#          'stationName': '캠퍼스타운',
#          'x': '126.662085',
#          'y': '37.388205'}]}},
#      {'trafficType': 3, 'distance': 87, 'sectionTime': 1},
#      {'trafficType': 2,
#       'distance': 808,
#       'sectionTime': 7,
#       'stationCount': 1,
#       'lane': [{'busNo': '81', 'type': 11, 'busID': 21269},
#        {'busNo': '9', 'type': 11, 'busID': 21204}],
#       'startName': '캠퍼스타운역',
#       'startX': 126.661564,
#       'startY': 37.387538,
#       'endName': '테크노파크역',
#       'endX': 126.65601,
#       'endY': 37.381762,
#       'startID': 193477,
#       'endID': 193476,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 193477,
#          'stationName': '캠퍼스타운역',
#          'x': '126.661564',
#          'y': '37.387538'},
#         {'index': 1,
#          'stationID': 193476,
#          'stationName': '테크노파크역',
#          'x': '126.65601',
#          'y': '37.381762'}]}},
#      {'trafficType': 3, 'distance': 108, 'sectionTime': 2}]},
#    {'pathType': 3,
#     'info': {'trafficDistance': 10240.0,
#      'totalWalk': 481,
#      'totalTime': 38,
#      'payment': 1350,
#      'busTransitCount': 1,
#      'subwayTransitCount': 1,
#      'mapObj': '21065:1:18:21@20001:2:20125:20134',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '테크노파크',
#      'totalStationCount': 12,
#      'busStationCount': 3,
#      'subwayStationCount': 9,
#      'totalDistance': 10721.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 1340,
#       'sectionTime': 9,
#       'stationCount': 3,
#       'lane': [{'busNo': '534', 'type': 12, 'busID': 21065}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '올림픽공원',
#       'endX': 126.699439,
#       'endY': 37.449654,
#       'startID': 181144,
#       'endID': 122483,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181153,
#          'stationName': '시청광장입구',
#          'x': '126.703227',
#          'y': '37.450164'},
#         {'index': 3,
#          'stationID': 122483,
#          'stationName': '올림픽공원',
#          'x': '126.699439',
#          'y': '37.449654'}]}},
#      {'trafficType': 3, 'distance': 145, 'sectionTime': 2},
#      {'trafficType': 1,
#       'distance': 8900,
#       'sectionTime': 22,
#       'stationCount': 9,
#       'lane': [{'name': '인천 1호선', 'subwayCode': 21, 'subwayCityCode': 2000}],
#       'startName': '예술회관',
#       'startX': 126.701016,
#       'startY': 37.449311,
#       'endName': '테크노파크',
#       'endX': 126.656407,
#       'endY': 37.382298,
#       'way': '테크노파크',
#       'wayCode': 2,
#       'door': 'null',
#       'startID': 20125,
#       'endID': 20134,
#       'startExitNo': '9',
#       'startExitX': 126.7004190841206,
#       'startExitY': 37.44998830339537,
#       'endExitNo': '2',
#       'endExitX': 126.65681598092114,
#       'endExitY': 37.38156412193719,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 20125,
#          'stationName': '예술회관',
#          'x': '126.701016',
#          'y': '37.449312'},
#         {'index': 1,
#          'stationID': 20126,
#          'stationName': '인천터미널',
#          'x': '126.699664',
#          'y': '37.441857'},
#         {'index': 2,
#          'stationID': 20127,
#          'stationName': '문학경기장',
#          'x': '126.698344',
#          'y': '37.434959'},
#         {'index': 3,
#          'stationID': 20128,
#          'stationName': '선학',
#          'x': '126.69893',
#          'y': '37.426963'},
#         {'index': 4,
#          'stationID': 20129,
#          'stationName': '신연수',
#          'x': '126.694023',
#          'y': '37.418062'},
#         {'index': 5,
#          'stationID': 20130,
#          'stationName': '원인재',
#          'x': '126.687844',
#          'y': '37.412342'},
#         {'index': 6,
#          'stationID': 20131,
#          'stationName': '동춘',
#          'x': '126.680956',
#          'y': '37.404688'},
#         {'index': 7,
#          'stationID': 20132,
#          'stationName': '동막',
#          'x': '126.673606',
#          'y': '37.398135'},
#         {'index': 8,
#          'stationID': 20133,
#          'stationName': '캠퍼스타운',
#          'x': '126.662085',
#          'y': '37.388205'},
#         {'index': 9,
#          'stationID': 20134,
#          'stationName': '테크노파크',
#          'x': '126.656412',
#          'y': '37.382306'}]}},
#      {'trafficType': 3, 'distance': 113, 'sectionTime': 2}]},
#    {'pathType': 3,
#     'info': {'trafficDistance': 10521.0,
#      'totalWalk': 640,
#      'totalTime': 41,
#      'payment': 1350,
#      'busTransitCount': 1,
#      'subwayTransitCount': 1,
#      'mapObj': '21007:1:99:101@20001:2:20124:20134',
#      'firstStartStation': '인천시청후문',
#      'lastEndStation': '테크노파크',
#      'totalStationCount': 12,
#      'busStationCount': 2,
#      'subwayStationCount': 10,
#      'totalDistance': 11161.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 134, 'sectionTime': 2},
#      {'trafficType': 2,
#       'distance': 621,
#       'sectionTime': 7,
#       'stationCount': 2,
#       'lane': [{'busNo': '8', 'type': 11, 'busID': 21007},
#        {'busNo': '33', 'type': 11, 'busID': 21028}],
#       'startName': '인천시청후문',
#       'startX': 126.704773,
#       'startY': 37.456885,
#       'endName': '현대아파트',
#       'endX': 126.697792,
#       'endY': 37.457322,
#       'startID': 181137,
#       'endID': 181289,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181137,
#          'stationName': '인천시청후문',
#          'x': '126.704773',
#          'y': '37.456885'},
#         {'index': 1,
#          'stationID': 181287,
#          'stationName': '극동. 금호아파트',
#          'x': '126.699286',
#          'y': '37.457185'},
#         {'index': 2,
#          'stationID': 181289,
#          'stationName': '현대아파트',
#          'x': '126.697792',
#          'y': '37.457322'}]}},
#      {'trafficType': 3, 'distance': 393, 'sectionTime': 6},
#      {'trafficType': 1,
#       'distance': 9900,
#       'sectionTime': 24,
#       'stationCount': 10,
#       'lane': [{'name': '인천 1호선', 'subwayCode': 21, 'subwayCityCode': 2000}],
#       'startName': '인천시청',
#       'startX': 126.702217,
#       'startY': 37.457614,
#       'endName': '테크노파크',
#       'endX': 126.656407,
#       'endY': 37.382298,
#       'way': '테크노파크',
#       'wayCode': 2,
#       'door': 'null',
#       'startID': 20124,
#       'endID': 20134,
#       'startExitNo': '8',
#       'startExitX': 126.70085819914428,
#       'startExitY': 37.45709783239656,
#       'endExitNo': '2',
#       'endExitX': 126.65681598092114,
#       'endExitY': 37.38156412193719,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 20124,
#          'stationName': '인천시청',
#          'x': '126.70222',
#          'y': '37.457619'},
#         {'index': 1,
#          'stationID': 20125,
#          'stationName': '예술회관',
#          'x': '126.701016',
#          'y': '37.449312'},
#         {'index': 2,
#          'stationID': 20126,
#          'stationName': '인천터미널',
#          'x': '126.699664',
#          'y': '37.441857'},
#         {'index': 3,
#          'stationID': 20127,
#          'stationName': '문학경기장',
#          'x': '126.698344',
#          'y': '37.434959'},
#         {'index': 4,
#          'stationID': 20128,
#          'stationName': '선학',
#          'x': '126.69893',
#          'y': '37.426963'},
#         {'index': 5,
#          'stationID': 20129,
#          'stationName': '신연수',
#          'x': '126.694023',
#          'y': '37.418062'},
#         {'index': 6,
#          'stationID': 20130,
#          'stationName': '원인재',
#          'x': '126.687844',
#          'y': '37.412342'},
#         {'index': 7,
#          'stationID': 20131,
#          'stationName': '동춘',
#          'x': '126.680956',
#          'y': '37.404688'},
#         {'index': 8,
#          'stationID': 20132,
#          'stationName': '동막',
#          'x': '126.673606',
#          'y': '37.398135'},
#         {'index': 9,
#          'stationID': 20133,
#          'stationName': '캠퍼스타운',
#          'x': '126.662085',
#          'y': '37.388205'},
#         {'index': 10,
#          'stationID': 20134,
#          'stationName': '테크노파크',
#          'x': '126.656412',
#          'y': '37.382306'}]}},
#      {'trafficType': 3, 'distance': 113, 'sectionTime': 2}]},
#    {'pathType': 2,
#     'info': {'trafficDistance': 14391.0,
#      'totalWalk': 1087,
#      'totalTime': 63,
#      'payment': 1250,
#      'busTransitCount': 1,
#      'subwayTransitCount': 0,
#      'mapObj': '21270:1:30:58',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '웰카운티',
#      'totalStationCount': 28,
#      'busStationCount': 28,
#      'subwayStationCount': 0,
#      'totalDistance': 15478.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 14391,
#       'sectionTime': 47,
#       'stationCount': 28,
#       'lane': [{'busNo': '82', 'type': 11, 'busID': 21270}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '웰카운티',
#       'endX': 126.647534,
#       'endY': 37.380278,
#       'startID': 181144,
#       'endID': 152824,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181155,
#          'stationName': '길병원사거리',
#          'x': '126.707147',
#          'y': '37.447639'},
#         {'index': 3,
#          'stationID': 181160,
#          'stationName': '성리초등학교',
#          'x': '126.706702',
#          'y': '37.444607'},
#         {'index': 4,
#          'stationID': 181167,
#          'stationName': '구월도매시장',
#          'x': '126.704907',
#          'y': '37.443191'},
#         {'index': 5,
#          'stationID': 181172,
#          'stationName': '롯데백화점(인천터미널)',
#          'x': '126.701785',
#          'y': '37.443391'},
#         {'index': 6,
#          'stationID': 181358,
#          'stationName': '풍림아파트',
#          'x': '126.698598',
#          'y': '37.443356'},
#         {'index': 7,
#          'stationID': 181362,
#          'stationName': '인명여자고등학교',
#          'x': '126.698238',
#          'y': '37.440658'},
#         {'index': 8,
#          'stationID': 181365,
#          'stationName': '문학경기장(월드컵경기장)',
#          'x': '126.69271',
#          'y': '37.438822'},
#         {'index': 9,
#          'stationID': 187418,
#          'stationName': '인천향교. 인천도호부청사',
#          'x': '126.686431',
#          'y': '37.438626'},
#         {'index': 10,
#          'stationID': 187413,
#          'stationName': '문학초등학교',
#          'x': '126.682565',
#          'y': '37.438718'},
#         {'index': 11,
#          'stationID': 122638,
#          'stationName': '문학고개',
#          'x': '126.678481',
#          'y': '37.439637'},
#         {'index': 12,
#          'stationID': 122533,
#          'stationName': '청학사거리',
#          'x': '126.669379',
#          'y': '37.425884'},
#         {'index': 13,
#          'stationID': 181477,
#          'stationName': '성호아파트',
#          'x': '126.668135',
#          'y': '37.422734'},
#         {'index': 14,
#          'stationID': 86032,
#          'stationName': '송도파크레인입구',
#          'x': '126.657876',
#          'y': '37.405039'},
#         {'index': 15,
#          'stationID': 193283,
#          'stationName': '더프라우',
#          'x': '126.651005',
#          'y': '37.397032'},
#         {'index': 16,
#          'stationID': 80683,
#          'stationName': '더샵그린애비뉴',
#          'x': '126.6477',
#          'y': '37.398742'},
#         {'index': 17,
#          'stationID': 196891,
#          'stationName': '엑스포빌리지9단지',
#          'x': '126.644532',
#          'y': '37.400932'},
#         {'index': 18,
#          'stationID': 195163,
#          'stationName': '엑스포빌리지 10단지',
#          'x': '126.642851',
#          'y': '37.402075'},
#         {'index': 19,
#          'stationID': 85237,
#          'stationName': '커넬워크(4동)',
#          'x': '126.640657',
#          'y': '37.402203'},
#         {'index': 20,
#          'stationID': 195162,
#          'stationName': '국제학교',
#          'x': '126.641093',
#          'y': '37.399955'},
#         {'index': 21,
#          'stationID': 81090,
#          'stationName': '송도푸르지오하버뷰',
#          'x': '126.640871',
#          'y': '37.397871'},
#         {'index': 22,
#          'stationID': 195176,
#          'stationName': 'GS자이아파트',
#          'x': '126.642267',
#          'y': '37.396896'},
#         {'index': 23,
#          'stationID': 80365,
#          'stationName': '자이하버뷰',
#          'x': '126.644427',
#          'y': '37.395479'},
#         {'index': 24,
#          'stationID': 193345,
#          'stationName': '송도푸르지오월드마크',
#          'x': '126.64633',
#          'y': '37.392645'},
#         {'index': 25,
#          'stationID': 152820,
#          'stationName': '컨벤시아',
#          'x': '126.64723',
#          'y': '37.389699'},
#         {'index': 26,
#          'stationID': 152244,
#          'stationName': '송도컨벤시아',
#          'x': '126.648456',
#          'y': '37.388668'},
#         {'index': 27,
#          'stationID': 152823,
#          'stationName': '인천가톨릭대',
#          'x': '126.645077',
#          'y': '37.383818'},
#         {'index': 28,
#          'stationID': 152824,
#          'stationName': '웰카운티',
#          'x': '126.647534',
#          'y': '37.380278'}]}},
#      {'trafficType': 3, 'distance': 864, 'sectionTime': 13}]},
#    {'pathType': 2,
#     'info': {'trafficDistance': 10226.0,
#      'totalWalk': 331,
#      'totalTime': 34,
#      'payment': 1750,
#      'busTransitCount': 2,
#      'subwayTransitCount': 0,
#      'mapObj': '21124:1:5:14@21269:1:40:42',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '테크노파크역',
#      'totalStationCount': 11,
#      'busStationCount': 11,
#      'subwayStationCount': 0,
#      'totalDistance': 10557.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 7867,
#       'sectionTime': 19,
#       'stationCount': 9,
#       'lane': [{'busNo': '304', 'type': 2, 'busID': 21124}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '동막역(3번출구)',
#       'endX': 126.672746,
#       'endY': 37.398287,
#       'startID': 181144,
#       'endID': 194779,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181160,
#          'stationName': '성리초등학교',
#          'x': '126.706702',
#          'y': '37.444607'},
#         {'index': 3,
#          'stationID': 181171,
#          'stationName': '종합터미널',
#          'x': '126.702504',
#          'y': '37.441624'},
#         {'index': 4,
#          'stationID': 206392,
#          'stationName': '문학경기장(박태환수영장)',
#          'x': '126.698304',
#          'y': '37.43554'},
#         {'index': 5,
#          'stationID': 181516,
#          'stationName': '선학역',
#          'x': '126.698726',
#          'y': '37.42749'},
#         {'index': 6,
#          'stationID': 187445,
#          'stationName': '신연수역(3번출구)',
#          'x': '126.693135',
#          'y': '37.417634'},
#         {'index': 7,
#          'stationID': 187438,
#          'stationName': '원인재역(6번출구)',
#          'x': '126.688311',
#          'y': '37.413111'},
#         {'index': 8,
#          'stationID': 187378,
#          'stationName': '동춘역',
#          'x': '126.679694',
#          'y': '37.404627'},
#         {'index': 9,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'}]}},
#      {'trafficType': 3, 'distance': 0, 'sectionTime': 0},
#      {'trafficType': 2,
#       'distance': 2359,
#       'sectionTime': 10,
#       'stationCount': 2,
#       'lane': [{'busNo': '81', 'type': 11, 'busID': 21269},
#        {'busNo': '9', 'type': 11, 'busID': 21204}],
#       'startName': '동막역(3번출구)',
#       'startX': 126.672746,
#       'startY': 37.398287,
#       'endName': '테크노파크역',
#       'endX': 126.65601,
#       'endY': 37.381762,
#       'startID': 194779,
#       'endID': 193476,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'},
#         {'index': 1,
#          'stationID': 193477,
#          'stationName': '캠퍼스타운역',
#          'x': '126.661564',
#          'y': '37.387538'},
#         {'index': 2,
#          'stationID': 193476,
#          'stationName': '테크노파크역',
#          'x': '126.65601',
#          'y': '37.381762'}]}},
#      {'trafficType': 3, 'distance': 108, 'sectionTime': 2}]},
#    {'pathType': 2,
#     'info': {'trafficDistance': 10877.0,
#      'totalWalk': 331,
#      'totalTime': 40,
#      'payment': 1750,
#      'busTransitCount': 2,
#      'subwayTransitCount': 0,
#      'mapObj': '21135:1:7:26@21269:1:40:42',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '테크노파크역',
#      'totalStationCount': 21,
#      'busStationCount': 21,
#      'subwayStationCount': 0,
#      'totalDistance': 11208.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 8518,
#       'sectionTime': 25,
#       'stationCount': 19,
#       'lane': [{'busNo': '303', 'type': 2, 'busID': 21135}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '동막역(3번출구)',
#       'endX': 126.672746,
#       'endY': 37.398287,
#       'startID': 181144,
#       'endID': 194779,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181155,
#          'stationName': '길병원사거리',
#          'x': '126.707147',
#          'y': '37.447639'},
#         {'index': 3,
#          'stationID': 181160,
#          'stationName': '성리초등학교',
#          'x': '126.706702',
#          'y': '37.444607'},
#         {'index': 4,
#          'stationID': 181167,
#          'stationName': '구월도매시장',
#          'x': '126.704907',
#          'y': '37.443191'},
#         {'index': 5,
#          'stationID': 181172,
#          'stationName': '롯데백화점(인천터미널)',
#          'x': '126.701785',
#          'y': '37.443391'},
#         {'index': 6,
#          'stationID': 181358,
#          'stationName': '풍림아파트',
#          'x': '126.698598',
#          'y': '37.443356'},
#         {'index': 7,
#          'stationID': 181362,
#          'stationName': '인명여자고등학교',
#          'x': '126.698238',
#          'y': '37.440658'},
#         {'index': 8,
#          'stationID': 206392,
#          'stationName': '문학경기장(박태환수영장)',
#          'x': '126.698304',
#          'y': '37.43554'},
#         {'index': 9,
#          'stationID': 181517,
#          'stationName': '선학체육관(하키경기장)',
#          'x': '126.698378',
#          'y': '37.431937'},
#         {'index': 10,
#          'stationID': 181516,
#          'stationName': '선학역',
#          'x': '126.698726',
#          'y': '37.42749'},
#         {'index': 11,
#          'stationID': 181508,
#          'stationName': '연수병원',
#          'x': '126.696323',
#          'y': '37.423391'},
#         {'index': 12,
#          'stationID': 181499,
#          'stationName': '연수초등학교',
#          'x': '126.693383',
#          'y': '37.422223'},
#         {'index': 13,
#          'stationID': 181501,
#          'stationName': '신연수(풍림아파트)',
#          'x': '126.691716',
#          'y': '37.418681'},
#         {'index': 14,
#          'stationID': 181458,
#          'stationName': '대우아파트',
#          'x': '126.688011',
#          'y': '37.416703'},
#         {'index': 15,
#          'stationID': 182512,
#          'stationName': '연수주공3차아파트',
#          'x': '126.686193',
#          'y': '37.415359'},
#         {'index': 16,
#          'stationID': 181454,
#          'stationName': '대동아파트',
#          'x': '126.683099',
#          'y': '37.41272'},
#         {'index': 17,
#          'stationID': 206594,
#          'stationName': '연수구청입구',
#          'x': '126.679886',
#          'y': '37.409792'},
#         {'index': 18,
#          'stationID': 187378,
#          'stationName': '동춘역',
#          'x': '126.679694',
#          'y': '37.404627'},
#         {'index': 19,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'}]}},
#      {'trafficType': 3, 'distance': 0, 'sectionTime': 0},
#      {'trafficType': 2,
#       'distance': 2359,
#       'sectionTime': 10,
#       'stationCount': 2,
#       'lane': [{'busNo': '81', 'type': 11, 'busID': 21269},
#        {'busNo': '9', 'type': 11, 'busID': 21204}],
#       'startName': '동막역(3번출구)',
#       'startX': 126.672746,
#       'startY': 37.398287,
#       'endName': '테크노파크역',
#       'endX': 126.65601,
#       'endY': 37.381762,
#       'startID': 194779,
#       'endID': 193476,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'},
#         {'index': 1,
#          'stationID': 193477,
#          'stationName': '캠퍼스타운역',
#          'x': '126.661564',
#          'y': '37.387538'},
#         {'index': 2,
#          'stationID': 193476,
#          'stationName': '테크노파크역',
#          'x': '126.65601',
#          'y': '37.381762'}]}},
#      {'trafficType': 3, 'distance': 108, 'sectionTime': 2}]},
#    {'pathType': 2,
#     'info': {'trafficDistance': 13369.0,
#      'totalWalk': 242,
#      'totalTime': 54,
#      'payment': 1250,
#      'busTransitCount': 2,
#      'subwayTransitCount': 0,
#      'mapObj': '21007:1:99:106@21269:1:22:42',
#      'firstStartStation': '인천시청후문',
#      'lastEndStation': '테크노파크역',
#      'totalStationCount': 27,
#      'busStationCount': 27,
#      'subwayStationCount': 0,
#      'totalDistance': 13611.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 134, 'sectionTime': 2},
#      {'trafficType': 2,
#       'distance': 2287,
#       'sectionTime': 13,
#       'stationCount': 7,
#       'lane': [{'busNo': '8', 'type': 11, 'busID': 21007}],
#       'startName': '인천시청후문',
#       'startX': 126.704773,
#       'startY': 37.456885,
#       'endName': '(구)시민회관 사거리',
#       'endX': 126.679914,
#       'endY': 37.457754,
#       'startID': 181137,
#       'endID': 189162,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181137,
#          'stationName': '인천시청후문',
#          'x': '126.704773',
#          'y': '37.456885'},
#         {'index': 1,
#          'stationID': 181287,
#          'stationName': '극동. 금호아파트',
#          'x': '126.699286',
#          'y': '37.457185'},
#         {'index': 2,
#          'stationID': 181289,
#          'stationName': '현대아파트',
#          'x': '126.697792',
#          'y': '37.457322'},
#         {'index': 3,
#          'stationID': 122830,
#          'stationName': '인천교회',
#          'x': '126.694905',
#          'y': '37.457587'},
#         {'index': 4,
#          'stationID': 181327,
#          'stationName': '석바위시장역',
#          'x': '126.692199',
#          'y': '37.457828'},
#         {'index': 5,
#          'stationID': 181321,
#          'stationName': '석바위',
#          'x': '126.688521',
#          'y': '37.458102'},
#         {'index': 6,
#          'stationID': 181320,
#          'stationName': '주안현대아파트',
#          'x': '126.68438',
#          'y': '37.458345'},
#         {'index': 7,
#          'stationID': 189162,
#          'stationName': '(구)시민회관 사거리',
#          'x': '126.679914',
#          'y': '37.457754'}]}},
#      {'trafficType': 3, 'distance': 0, 'sectionTime': 0},
#      {'trafficType': 2,
#       'distance': 11082,
#       'sectionTime': 37,
#       'stationCount': 20,
#       'lane': [{'busNo': '81', 'type': 11, 'busID': 21269}],
#       'startName': '(구)시민회관 사거리',
#       'startX': 126.679914,
#       'startY': 37.457754,
#       'endName': '테크노파크역',
#       'endX': 126.65601,
#       'endY': 37.381762,
#       'startID': 189162,
#       'endID': 193476,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 189162,
#          'stationName': '(구)시민회관 사거리',
#          'x': '126.679914',
#          'y': '37.457754'},
#         {'index': 1,
#          'stationID': 181333,
#          'stationName': '재흥시장',
#          'x': '126.679785',
#          'y': '37.454167'},
#         {'index': 2,
#          'stationID': 181337,
#          'stationName': '남광로얄아파트',
#          'x': '126.679577',
#          'y': '37.44993'},
#         {'index': 3,
#          'stationID': 182803,
#          'stationName': '신기.남부종합시장(진흥사거리)',
#          'x': '126.679231',
#          'y': '37.447727'},
#         {'index': 4,
#          'stationID': 182808,
#          'stationName': '신동아아파트',
#          'x': '126.678482',
#          'y': '37.443403'},
#         {'index': 5,
#          'stationID': 187376,
#          'stationName': '신동아3차아파트',
#          'x': '126.678017',
#          'y': '37.44092'},
#         {'index': 6,
#          'stationID': 84350,
#          'stationName': '청학사거리',
#          'x': '126.670367',
#          'y': '37.424931'},
#         {'index': 7,
#          'stationID': 181442,
#          'stationName': '효정아파트',
#          'x': '126.672833',
#          'y': '37.424742'},
#         {'index': 8,
#          'stationID': 152848,
#          'stationName': '동남아파트',
#          'x': '126.67608',
#          'y': '37.424499'},
#         {'index': 9,
#          'stationID': 181484,
#          'stationName': '태경아파트',
#          'x': '126.682561',
#          'y': '37.423455'},
#         {'index': 10,
#          'stationID': 181464,
#          'stationName': '문남초등학교',
#          'x': '126.680398',
#          'y': '37.420529'},
#         {'index': 11,
#          'stationID': 89800,
#          'stationName': '연수역북측입구',
#          'x': '126.679201',
#          'y': '37.419227'},
#         {'index': 12,
#          'stationID': 89802,
#          'stationName': '국민은행연수중앙지점',
#          'x': '126.676143',
#          'y': '37.414526'},
#         {'index': 13,
#          'stationID': 181447,
#          'stationName': '롯데아파트',
#          'x': '126.674435',
#          'y': '37.412704'},
#         {'index': 14,
#          'stationID': 122767,
#          'stationName': '연수여자고등학교',
#          'x': '126.673157',
#          'y': '37.411501'},
#         {'index': 15,
#          'stationID': 181539,
#          'stationName': '동춘마을아파트',
#          'x': '126.671913',
#          'y': '37.410333'},
#         {'index': 16,
#          'stationID': 182532,
#          'stationName': '롯데슈퍼',
#          'x': '126.67321',
#          'y': '37.407248'},
#         {'index': 17,
#          'stationID': 90973,
#          'stationName': '대우삼환아파트',
#          'x': '126.676594',
#          'y': '37.404926'},
#         {'index': 18,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'},
#         {'index': 19,
#          'stationID': 193477,
#          'stationName': '캠퍼스타운역',
#          'x': '126.661564',
#          'y': '37.387538'},
#         {'index': 20,
#          'stationID': 193476,
#          'stationName': '테크노파크역',
#          'x': '126.65601',
#          'y': '37.381762'}]}},
#      {'trafficType': 3, 'distance': 108, 'sectionTime': 2}]},
#    {'pathType': 2,
#     'info': {'trafficDistance': 12004.0,
#      'totalWalk': 620,
#      'totalTime': 45,
#      'payment': 1750,
#      'busTransitCount': 2,
#      'subwayTransitCount': 0,
#      'mapObj': '21124:1:5:14@21006:1:107:116',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '인천대미래관',
#      'totalStationCount': 18,
#      'busStationCount': 18,
#      'subwayStationCount': 0,
#      'totalDistance': 12624.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 7867,
#       'sectionTime': 19,
#       'stationCount': 9,
#       'lane': [{'busNo': '304', 'type': 2, 'busID': 21124}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '동막역(3번출구)',
#       'endX': 126.672746,
#       'endY': 37.398287,
#       'startID': 181144,
#       'endID': 194779,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181160,
#          'stationName': '성리초등학교',
#          'x': '126.706702',
#          'y': '37.444607'},
#         {'index': 3,
#          'stationID': 181171,
#          'stationName': '종합터미널',
#          'x': '126.702504',
#          'y': '37.441624'},
#         {'index': 4,
#          'stationID': 206392,
#          'stationName': '문학경기장(박태환수영장)',
#          'x': '126.698304',
#          'y': '37.43554'},
#         {'index': 5,
#          'stationID': 181516,
#          'stationName': '선학역',
#          'x': '126.698726',
#          'y': '37.42749'},
#         {'index': 6,
#          'stationID': 187445,
#          'stationName': '신연수역(3번출구)',
#          'x': '126.693135',
#          'y': '37.417634'},
#         {'index': 7,
#          'stationID': 187438,
#          'stationName': '원인재역(6번출구)',
#          'x': '126.688311',
#          'y': '37.413111'},
#         {'index': 8,
#          'stationID': 187378,
#          'stationName': '동춘역',
#          'x': '126.679694',
#          'y': '37.404627'},
#         {'index': 9,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'}]}},
#      {'trafficType': 3, 'distance': 0, 'sectionTime': 0},
#      {'trafficType': 2,
#       'distance': 4137,
#       'sectionTime': 17,
#       'stationCount': 9,
#       'lane': [{'busNo': '6', 'type': 11, 'busID': 21006}],
#       'startName': '동막역(3번출구)',
#       'startX': 126.672746,
#       'startY': 37.398287,
#       'endName': '인천대미래관',
#       'endX': 126.652978,
#       'endY': 37.382737,
#       'startID': 194779,
#       'endID': 150931,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'},
#         {'index': 1,
#          'stationID': 122880,
#          'stationName': '성지아파트',
#          'x': '126.661068',
#          'y': '37.390028'},
#         {'index': 2,
#          'stationID': 122876,
#          'stationName': '신송고등학교',
#          'x': '126.658831',
#          'y': '37.391372'},
#         {'index': 3,
#          'stationID': 121415,
#          'stationName': '송도풍림아이원4단지',
#          'x': '126.656776',
#          'y': '37.392637'},
#         {'index': 4,
#          'stationID': 123009,
#          'stationName': '먼우금초등학교',
#          'x': '126.65265',
#          'y': '37.392843'},
#         {'index': 5,
#          'stationID': 122871,
#          'stationName': '송도더샵퍼스트월드D동',
#          'x': '126.649966',
#          'y': '37.390136'},
#         {'index': 6,
#          'stationID': 206117,
#          'stationName': '송도컨벤시아',
#          'x': '126.649261',
#          'y': '37.388488'},
#         {'index': 7,
#          'stationID': 206124,
#          'stationName': '의과학연구소',
#          'x': '126.651992',
#          'y': '37.386087'},
#         {'index': 8,
#          'stationID': 122872,
#          'stationName': '생산기술연구원',
#          'x': '126.650786',
#          'y': '37.384064'},
#         {'index': 9,
#          'stationID': 150931,
#          'stationName': '인천대미래관',
#          'x': '126.652978',
#          'y': '37.382737'}]}},
#      {'trafficType': 3, 'distance': 397, 'sectionTime': 6}]},
#    {'pathType': 2,
#     'info': {'trafficDistance': 13932.0,
#      'totalWalk': 331,
#      'totalTime': 54,
#      'payment': 1250,
#      'busTransitCount': 2,
#      'subwayTransitCount': 0,
#      'mapObj': '21043:1:147:164@21269:1:35:42',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '테크노파크역',
#      'totalStationCount': 24,
#      'busStationCount': 24,
#      'subwayStationCount': 0,
#      'totalDistance': 14263.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 9338,
#       'sectionTime': 32,
#       'stationCount': 17,
#       'lane': [{'busNo': '103', 'type': 2, 'busID': 21043}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '롯데아파트',
#       'endX': 126.674435,
#       'endY': 37.412704,
#       'startID': 181144,
#       'endID': 181447,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181155,
#          'stationName': '길병원사거리',
#          'x': '126.707147',
#          'y': '37.447639'},
#         {'index': 3,
#          'stationID': 181160,
#          'stationName': '성리초등학교',
#          'x': '126.706702',
#          'y': '37.444607'},
#         {'index': 4,
#          'stationID': 181171,
#          'stationName': '종합터미널',
#          'x': '126.702504',
#          'y': '37.441624'},
#         {'index': 5,
#          'stationID': 182530,
#          'stationName': '승기천',
#          'x': '126.707151',
#          'y': '37.434908'},
#         {'index': 6,
#          'stationID': 182527,
#          'stationName': '도림동입구',
#          'x': '126.70852',
#          'y': '37.419668'},
#         {'index': 7,
#          'stationID': 182525,
#          'stationName': '상진정공',
#          'x': '126.707659',
#          'y': '37.418523'},
#         {'index': 8,
#          'stationID': 182521,
#          'stationName': '공단회관',
#          'x': '126.704733',
#          'y': '37.414563'},
#         {'index': 9,
#          'stationID': 182516,
#          'stationName': '세우산업',
#          'x': '126.70268',
#          'y': '37.411792'},
#         {'index': 10,
#          'stationID': 182564,
#          'stationName': '남동공단2호공원',
#          'x': '126.699379',
#          'y': '37.407332'},
#         {'index': 11,
#          'stationID': 182566,
#          'stationName': '남동공단 우체국',
#          'x': '126.694588',
#          'y': '37.408757'},
#         {'index': 12,
#          'stationID': 182568,
#          'stationName': '인천인력개발원',
#          'x': '126.691962',
#          'y': '37.407791'},
#         {'index': 13,
#          'stationID': 182537,
#          'stationName': '공단소방서',
#          'x': '126.689117',
#          'y': '37.405119'},
#         {'index': 14,
#          'stationID': 182534,
#          'stationName': '남동대교',
#          'x': '126.685039',
#          'y': '37.407056'},
#         {'index': 15,
#          'stationID': 181521,
#          'stationName': '우성1차아파트',
#          'x': '126.681659',
#          'y': '37.409181'},
#         {'index': 16,
#          'stationID': 181450,
#          'stationName': '동아금호아파트',
#          'x': '126.677899',
#          'y': '37.411626'},
#         {'index': 17,
#          'stationID': 181447,
#          'stationName': '롯데아파트',
#          'x': '126.674435',
#          'y': '37.412704'}]}},
#      {'trafficType': 3, 'distance': 0, 'sectionTime': 0},
#      {'trafficType': 2,
#       'distance': 4594,
#       'sectionTime': 17,
#       'stationCount': 7,
#       'lane': [{'busNo': '81', 'type': 11, 'busID': 21269}],
#       'startName': '롯데아파트',
#       'startX': 126.674435,
#       'startY': 37.412704,
#       'endName': '테크노파크역',
#       'endX': 126.65601,
#       'endY': 37.381762,
#       'startID': 181447,
#       'endID': 193476,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181447,
#          'stationName': '롯데아파트',
#          'x': '126.674435',
#          'y': '37.412704'},
#         {'index': 1,
#          'stationID': 122767,
#          'stationName': '연수여자고등학교',
#          'x': '126.673157',
#          'y': '37.411501'},
#         {'index': 2,
#          'stationID': 181539,
#          'stationName': '동춘마을아파트',
# ...
#    {'pathType': 2,
#     'info': {'trafficDistance': 13150.0,
#      'totalWalk': 407,
#      'totalTime': 55,
#      'payment': 1250,
#      'busTransitCount': 2,
#      'subwayTransitCount': 0,
#      'mapObj': '21028:1:26:33@21269:1:22:42',
#      'firstStartStation': '인천시청후문',
#      'lastEndStation': '테크노파크역',
#      'totalStationCount': 27,
#      'busStationCount': 27,
#      'subwayStationCount': 0,
#      'totalDistance': 13557.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 134, 'sectionTime': 2},
#      {'trafficType': 2,
#       'distance': 2068,
#       'sectionTime': 12,
#       'stationCount': 7,
#       'lane': [{'busNo': '33', 'type': 11, 'busID': 21028}],
#       'startName': '인천시청후문',
#       'startX': 126.704773,
#       'startY': 37.456885,
#       'endName': '시민공원(문화창작지대)역',
#       'endX': 126.681506,
#       'endY': 37.458529,
#       'startID': 181137,
#       'endID': 181544,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181137,
#          'stationName': '인천시청후문',
#          'x': '126.704773',
#          'y': '37.456885'},
#         {'index': 1,
#          'stationID': 181287,
#          'stationName': '극동. 금호아파트',
#          'x': '126.699286',
#          'y': '37.457185'},
#         {'index': 2,
#          'stationID': 181289,
#          'stationName': '현대아파트',
#          'x': '126.697792',
#          'y': '37.457322'},
#         {'index': 3,
#          'stationID': 122830,
#          'stationName': '인천교회',
#          'x': '126.694905',
#          'y': '37.457587'},
#         {'index': 4,
#          'stationID': 181327,
#          'stationName': '석바위시장역',
#          'x': '126.692199',
#          'y': '37.457828'},
#         {'index': 5,
#          'stationID': 181321,
#          'stationName': '석바위',
#          'x': '126.688521',
#          'y': '37.458102'},
#         {'index': 6,
#          'stationID': 181320,
#          'stationName': '주안현대아파트',
#          'x': '126.68438',
#          'y': '37.458345'},
#         {'index': 7,
#          'stationID': 181544,
#          'stationName': '시민공원(문화창작지대)역',
#          'x': '126.681506',
#          'y': '37.458529'}]}},
#      {'trafficType': 3, 'distance': 165, 'sectionTime': 2},
#      {'trafficType': 2,
#       'distance': 11082,
#       'sectionTime': 37,
#       'stationCount': 20,
#       'lane': [{'busNo': '81', 'type': 11, 'busID': 21269}],
#       'startName': '(구)시민회관 사거리',
#       'startX': 126.679914,
#       'startY': 37.457754,
#       'endName': '테크노파크역',
#       'endX': 126.65601,
#       'endY': 37.381762,
#       'startID': 189162,
#       'endID': 193476,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 189162,
#          'stationName': '(구)시민회관 사거리',
#          'x': '126.679914',
#          'y': '37.457754'},
#         {'index': 1,
#          'stationID': 181333,
#          'stationName': '재흥시장',
#          'x': '126.679785',
#          'y': '37.454167'},
#         {'index': 2,
#          'stationID': 181337,
#          'stationName': '남광로얄아파트',
#          'x': '126.679577',
#          'y': '37.44993'},
#         {'index': 3,
#          'stationID': 182803,
#          'stationName': '신기.남부종합시장(진흥사거리)',
#          'x': '126.679231',
#          'y': '37.447727'},
#         {'index': 4,
#          'stationID': 182808,
#          'stationName': '신동아아파트',
#          'x': '126.678482',
#          'y': '37.443403'},
#         {'index': 5,
#          'stationID': 187376,
#          'stationName': '신동아3차아파트',
#          'x': '126.678017',
#          'y': '37.44092'},
#         {'index': 6,
#          'stationID': 84350,
#          'stationName': '청학사거리',
#          'x': '126.670367',
#          'y': '37.424931'},
#         {'index': 7,
#          'stationID': 181442,
#          'stationName': '효정아파트',
#          'x': '126.672833',
#          'y': '37.424742'},
#         {'index': 8,
#          'stationID': 152848,
#          'stationName': '동남아파트',
#          'x': '126.67608',
#          'y': '37.424499'},
#         {'index': 9,
#          'stationID': 181484,
#          'stationName': '태경아파트',
#          'x': '126.682561',
#          'y': '37.423455'},
#         {'index': 10,
#          'stationID': 181464,
#          'stationName': '문남초등학교',
#          'x': '126.680398',
#          'y': '37.420529'},
#         {'index': 11,
#          'stationID': 89800,
#          'stationName': '연수역북측입구',
#          'x': '126.679201',
#          'y': '37.419227'},
#         {'index': 12,
#          'stationID': 89802,
#          'stationName': '국민은행연수중앙지점',
#          'x': '126.676143',
#          'y': '37.414526'},
#         {'index': 13,
#          'stationID': 181447,
#          'stationName': '롯데아파트',
#          'x': '126.674435',
#          'y': '37.412704'},
#         {'index': 14,
#          'stationID': 122767,
#          'stationName': '연수여자고등학교',
#          'x': '126.673157',
#          'y': '37.411501'},
#         {'index': 15,
#          'stationID': 181539,
#          'stationName': '동춘마을아파트',
#          'x': '126.671913',
#          'y': '37.410333'},
#         {'index': 16,
#          'stationID': 182532,
#          'stationName': '롯데슈퍼',
#          'x': '126.67321',
#          'y': '37.407248'},
#         {'index': 17,
#          'stationID': 90973,
#          'stationName': '대우삼환아파트',
#          'x': '126.676594',
#          'y': '37.404926'},
#         {'index': 18,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'},
#         {'index': 19,
#          'stationID': 193477,
#          'stationName': '캠퍼스타운역',
#          'x': '126.661564',
#          'y': '37.387538'},
#         {'index': 20,
#          'stationID': 193476,
#          'stationName': '테크노파크역',
#          'x': '126.65601',
#          'y': '37.381762'}]}},
#      {'trafficType': 3, 'distance': 108, 'sectionTime': 2}]},
#    {'pathType': 2,
#     'info': {'trafficDistance': 14530.0,
#      'totalWalk': 620,
#      'totalTime': 62,
#      'payment': 1250,
#      'busTransitCount': 2,
#      'subwayTransitCount': 0,
#      'mapObj': '21043:1:147:162@21006:1:101:116',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '인천대미래관',
#      'totalStationCount': 30,
#      'busStationCount': 30,
#      'subwayStationCount': 0,
#      'totalDistance': 15150.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 8446,
#       'sectionTime': 29,
#       'stationCount': 15,
#       'lane': [{'busNo': '103', 'type': 2, 'busID': 21043}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '우성1차아파트',
#       'endX': 126.681659,
#       'endY': 37.409181,
#       'startID': 181144,
#       'endID': 181521,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181155,
#          'stationName': '길병원사거리',
#          'x': '126.707147',
#          'y': '37.447639'},
#         {'index': 3,
#          'stationID': 181160,
#          'stationName': '성리초등학교',
#          'x': '126.706702',
#          'y': '37.444607'},
#         {'index': 4,
#          'stationID': 181171,
#          'stationName': '종합터미널',
#          'x': '126.702504',
#          'y': '37.441624'},
#         {'index': 5,
#          'stationID': 182530,
#          'stationName': '승기천',
#          'x': '126.707151',
#          'y': '37.434908'},
#         {'index': 6,
#          'stationID': 182527,
#          'stationName': '도림동입구',
#          'x': '126.70852',
#          'y': '37.419668'},
#         {'index': 7,
#          'stationID': 182525,
#          'stationName': '상진정공',
#          'x': '126.707659',
#          'y': '37.418523'},
#         {'index': 8,
#          'stationID': 182521,
#          'stationName': '공단회관',
#          'x': '126.704733',
#          'y': '37.414563'},
#         {'index': 9,
#          'stationID': 182516,
#          'stationName': '세우산업',
#          'x': '126.70268',
#          'y': '37.411792'},
#         {'index': 10,
#          'stationID': 182564,
#          'stationName': '남동공단2호공원',
#          'x': '126.699379',
#          'y': '37.407332'},
#         {'index': 11,
#          'stationID': 182566,
#          'stationName': '남동공단 우체국',
#          'x': '126.694588',
#          'y': '37.408757'},
#         {'index': 12,
#          'stationID': 182568,
#          'stationName': '인천인력개발원',
#          'x': '126.691962',
#          'y': '37.407791'},
#         {'index': 13,
#          'stationID': 182537,
#          'stationName': '공단소방서',
#          'x': '126.689117',
#          'y': '37.405119'},
#         {'index': 14,
#          'stationID': 182534,
#          'stationName': '남동대교',
#          'x': '126.685039',
#          'y': '37.407056'},
#         {'index': 15,
#          'stationID': 181521,
#          'stationName': '우성1차아파트',
#          'x': '126.681659',
#          'y': '37.409181'}]}},
#      {'trafficType': 3, 'distance': 0, 'sectionTime': 0},
#      {'trafficType': 2,
#       'distance': 6084,
#       'sectionTime': 24,
#       'stationCount': 15,
#       'lane': [{'busNo': '6', 'type': 11, 'busID': 21006}],
#       'startName': '우성1차아파트',
#       'startX': 126.681659,
#       'startY': 37.409181,
#       'endName': '인천대미래관',
#       'endX': 126.652978,
#       'endY': 37.382737,
#       'startID': 181521,
#       'endID': 150931,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181521,
#          'stationName': '우성1차아파트',
#          'x': '126.681659',
#          'y': '37.409181'},
#         {'index': 1,
#          'stationID': 181523,
#          'stationName': '연수구청',
#          'x': '126.679005',
#          'y': '37.409782'},
#         {'index': 2,
#          'stationID': 181524,
#          'stationName': '삼성아파트',
#          'x': '126.677015',
#          'y': '37.407327'},
#         {'index': 3,
#          'stationID': 181526,
#          'stationName': '한양아파트2차',
#          'x': '126.675562',
#          'y': '37.40513'},
#         {'index': 4,
#          'stationID': 122663,
#          'stationName': '동막초등학교',
#          'x': '126.673496',
#          'y': '37.403188'},
#         {'index': 5,
#          'stationID': 187349,
#          'stationName': '풍림2차아파트',
#          'x': '126.674261',
#          'y': '37.402061'},
#         {'index': 6,
#          'stationID': 194779,
#          'stationName': '동막역(3번출구)',
#          'x': '126.672746',
#          'y': '37.398287'},
#         {'index': 7,
#          'stationID': 122880,
#          'stationName': '성지아파트',
#          'x': '126.661068',
#          'y': '37.390028'},
#         {'index': 8,
#          'stationID': 122876,
#          'stationName': '신송고등학교',
#          'x': '126.658831',
#          'y': '37.391372'},
#         {'index': 9,
#          'stationID': 121415,
#          'stationName': '송도풍림아이원4단지',
#          'x': '126.656776',
#          'y': '37.392637'},
#         {'index': 10,
#          'stationID': 123009,
#          'stationName': '먼우금초등학교',
#          'x': '126.65265',
#          'y': '37.392843'},
#         {'index': 11,
#          'stationID': 122871,
#          'stationName': '송도더샵퍼스트월드D동',
#          'x': '126.649966',
#          'y': '37.390136'},
#         {'index': 12,
#          'stationID': 206117,
#          'stationName': '송도컨벤시아',
#          'x': '126.649261',
#          'y': '37.388488'},
#         {'index': 13,
#          'stationID': 206124,
#          'stationName': '의과학연구소',
#          'x': '126.651992',
#          'y': '37.386087'},
#         {'index': 14,
#          'stationID': 122872,
#          'stationName': '생산기술연구원',
#          'x': '126.650786',
#          'y': '37.384064'},
#         {'index': 15,
#          'stationID': 150931,
#          'stationName': '인천대미래관',
#          'x': '126.652978',
#          'y': '37.382737'}]}},
#      {'trafficType': 3, 'distance': 397, 'sectionTime': 6}]},
#    {'pathType': 2,
#     'info': {'trafficDistance': 12633.0,
#      'totalWalk': 411,
#      'totalTime': 40,
#      'payment': 1750,
#      'busTransitCount': 2,
#      'subwayTransitCount': 0,
#      'mapObj': '21124:1:5:13@21153:1:68:79',
#      'firstStartStation': '구월중학교',
#      'lastEndStation': '테크노파크역',
#      'totalStationCount': 19,
#      'busStationCount': 19,
#      'subwayStationCount': 0,
#      'totalDistance': 13044.0,
#      'totalWalkTime': -1},
#     'subPath': [{'trafficType': 3, 'distance': 223, 'sectionTime': 3},
#      {'trafficType': 2,
#       'distance': 6932,
#       'sectionTime': 17,
#       'stationCount': 8,
#       'lane': [{'busNo': '304', 'type': 2, 'busID': 21124}],
#       'startName': '구월중학교',
#       'startX': 126.708247,
#       'startY': 37.455337,
#       'endName': '동춘역',
#       'endX': 126.679694,
#       'endY': 37.404627,
#       'startID': 181144,
#       'endID': 187378,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 181144,
#          'stationName': '구월중학교',
#          'x': '126.708247',
#          'y': '37.455337'},
#         {'index': 1,
#          'stationID': 181147,
#          'stationName': '길병원',
#          'x': '126.70776',
#          'y': '37.45207'},
#         {'index': 2,
#          'stationID': 181160,
#          'stationName': '성리초등학교',
#          'x': '126.706702',
#          'y': '37.444607'},
#         {'index': 3,
#          'stationID': 181171,
#          'stationName': '종합터미널',
#          'x': '126.702504',
#          'y': '37.441624'},
#         {'index': 4,
#          'stationID': 206392,
#          'stationName': '문학경기장(박태환수영장)',
#          'x': '126.698304',
#          'y': '37.43554'},
#         {'index': 5,
#          'stationID': 181516,
#          'stationName': '선학역',
#          'x': '126.698726',
#          'y': '37.42749'},
#         {'index': 6,
#          'stationID': 187445,
#          'stationName': '신연수역(3번출구)',
#          'x': '126.693135',
#          'y': '37.417634'},
#         {'index': 7,
#          'stationID': 187438,
#          'stationName': '원인재역(6번출구)',
#          'x': '126.688311',
#          'y': '37.413111'},
#         {'index': 8,
#          'stationID': 187378,
#          'stationName': '동춘역',
#          'x': '126.679694',
#          'y': '37.404627'}]}},
#      {'trafficType': 3, 'distance': 80, 'sectionTime': 1},
#      {'trafficType': 2,
#       'distance': 5701,
#       'sectionTime': 17,
#       'stationCount': 11,
#       'lane': [{'busNo': '320', 'type': 2, 'busID': 21153}],
#       'startName': '동춘역(이마트.스퀘어원)',
#       'startX': 126.68056,
#       'startY': 37.404817,
#       'endName': '테크노파크역',
#       'endX': 126.65601,
#       'endY': 37.381762,
#       'startID': 187373,
#       'endID': 193476,
#       'passStopList': {'stations': [{'index': 0,
#          'stationID': 187373,
#          'stationName': '동춘역(이마트.스퀘어원)',
#          'x': '126.68056',
#          'y': '37.404817'},
#         {'index': 1,
#          'stationID': 181521,
#          'stationName': '우성1차아파트',
#          'x': '126.681659',
#          'y': '37.409181'},
#         {'index': 2,
#          'stationID': 181450,
#          'stationName': '동아금호아파트',
#          'x': '126.677899',
#          'y': '37.411626'},
#         {'index': 3,
#          'stationID': 181447,
#          'stationName': '롯데아파트',
#          'x': '126.674435',
#          'y': '37.412704'},
#         {'index': 4,
#          'stationID': 122767,
#          'stationName': '연수여자고등학교',
#          'x': '126.673157',
#          'y': '37.411501'},
#         {'index': 5,
#          'stationID': 181539,
#          'stationName': '동춘마을아파트',
#          'x': '126.671913',
#          'y': '37.410333'},
#         {'index': 6,
#          'stationID': 181536,
#          'stationName': '건영아파트',
#          'x': '126.670002',
#          'y': '37.407897'},
#         {'index': 7,
#          'stationID': 181535,
#          'stationName': '대동아파트',
#          'x': '126.669768',
#          'y': '37.405137'},
#         {'index': 8,
#          'stationID': 181533,
#          'stationName': '동춘2동주민센터',
#          'x': '126.669522',
#          'y': '37.40245'},
#         {'index': 9,
#          'stationID': 181531,
#          'stationName': '동남아파트(무지개아파트)',
#          'x': '126.669395',
#          'y': '37.400682'},
#         {'index': 10,
#          'stationID': 193477,
#          'stationName': '캠퍼스타운역',
#          'x': '126.661564',
#          'y': '37.387538'},
#         {'index': 11,
#          'stationID': 193476,
#          'stationName': '테크노파크역',
#          'x': '126.65601',
#          'y': '37.381762'}]}},
#      {'trafficType': 3, 'distance': 108, 'sectionTime': 2}]}]}}

# %%
data['result']['searchType'] == 0 #도시내 교통만 뽑자
data['result']['path'] #path들이 들어있는 list
data['result']['path'][0]['info'] # path 전체에 대한 정보가 들어있는 dict
data['result']['path'][0]['info']['totalTime'] #전체 이동 시간
data['result']['path'][0]['info']['totalWalk'] #전체 도보 거리
data['result']['path'][0]['info']['mapObj'] #노선 그래픽 데이터
data['result']['path'][0]['info']
# Out:
# {'trafficDistance': 9900.0,
#  'totalWalk': 481,
#  'totalTime': 32,
#  'payment': 1250,
#  'busTransitCount': 0,
#  'subwayTransitCount': 1,
#  'mapObj': '20001:2:20124:20134',
#  'firstStartStation': '인천시청',
#  'lastEndStation': '테크노파크',
#  'totalStationCount': 10,
#  'busStationCount': 0,
#  'subwayStationCount': 10,
#  'totalDistance': 10381.0,
#  'totalWalkTime': -1}

# %%
(data['result']['path'][0]['subPath'][1]['startX'],data['result']['path'][0]['subPath'][1]['startY']) #출발 역 위경도
(data['result']['path'][0]['subPath'][1]['endX'],data['result']['path'][0]['subPath'][1]['endY']) #도착 역 위경도
# Out:
# (126.656407, 37.382298)

# %%
import pickle

# %%
bike = pickle.load(open('bike.txt','rb'))
std_dist = 9999
for idx in bike:
    
    distance = sample.distance(idx,sample.source)
    if distance < std_dist:
        std_dist = distance
        bike_spot = idx
std_dist, bike_spot
# Out:
# (0.7628274981063115, [37.50190344812883, 126.70735427241102])

# %%
m_ = folium.Map(location = bike_spot, zoom_start = 15)
folium.Marker(location = bike_spot, color = 'red').add_to(m_)
folium.Marker(location = sample.source).add_to(m_)
for i in bike:
    folium.Circle(location = i, radius = 10).add_to(m_)
m_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data['result']['path'][7]
# Out:
# {'pathType': 1,
#  'info': {'trafficDistance': 15600.0,
#   'totalWalk': 1331,
#   'totalTime': 70,
#   'payment': 1450,
#   'busTransitCount': 0,
#   'subwayTransitCount': 3,
#   'mapObj': '20002:2:20221:20230@20001:2:20124:20130@116:2:11127:11128',
#   'firstStartStation': '가정중앙시장',
#   'lastEndStation': '연수',
#   'totalStationCount': 16,
#   'busStationCount': 0,
#   'subwayStationCount': 16,
#   'totalDistance': 16931.0,
#   'totalWalkTime': -1},
#  'subPath': [{'trafficType': 3, 'distance': 626, 'sectionTime': 9},
#   {'trafficType': 1,
#    'distance': 9300,
#    'sectionTime': 19,
#    'stationCount': 9,
#    'lane': [{'name': '인천 2호선', 'subwayCode': 22, 'subwayCityCode': 2000}],
#    'startName': '가정중앙시장',
#    'startX': 126.676805,
#    'startY': 37.517467,
#    'endName': '인천시청',
#    'endX': 126.701133,
#    'endY': 37.456899,
#    'way': '인천시청',
#    'wayCode': 2,
#    'door': '1-1',
#    'startID': 20221,
#    'endID': 20230,
#    'startExitNo': '2',
#    'startExitX': 126.6766602073217,
#    'startExitY': 37.51756337850934,
#    'passStopList': {'stations': [{'index': 0,
#       'stationID': 20221,
#       'stationName': '가정중앙시장',
#       'x': '126.676815',
#       'y': '37.517471'},
#      {'index': 1,
#       'stationID': 20222,
#       'stationName': '석남(거북시장)',
#       'x': '126.676286',
#       'y': '37.50716'},
#      {'index': 2,
#       'stationID': 20223,
#       'stationName': '서부여성회관',
#       'x': '126.675857',
#       'y': '37.500303'},
#      {'index': 3,
#       'stationID': 20224,
#       'stationName': '인천가좌',
#       'x': '126.675237',
#       'y': '37.490035'},
#      {'index': 4,
#       'stationID': 20225,
#       'stationName': '가재울',
#       'x': '126.683833',
#       'y': '37.484106'},
#      {'index': 5,
#       'stationID': 20226,
#       'stationName': '주안국가산단(인천J밸리)',
#       'x': '126.68124',
#       'y': '37.473961'},
#      {'index': 6,
#       'stationID': 20227,
#       'stationName': '주안',
#       'x': '126.678963',
#       'y': '37.465078'},
#      {'index': 7,
#       'stationID': 20228,
#       'stationName': '시민공원(문화창작지대)',
#       'x': '126.681091',
#       'y': '37.458391'},
#      {'index': 8,
#       'stationID': 20229,
#       'stationName': '석바위시장',
#       'x': '126.692387',
#       'y': '37.457678'},
#      {'index': 9,
#       'stationID': 20230,
#       'stationName': '인천시청',
#       'x': '126.70114',
#       'y': '37.456899'}]}},
#   {'trafficType': 3, 'distance': 0, 'sectionTime': 0},
#   {'trafficType': 1,
#    'distance': 5400,
#    'sectionTime': 18,
#    'stationCount': 6,
#    'lane': [{'name': '인천 1호선', 'subwayCode': 21, 'subwayCityCode': 2000}],
#    'startName': '인천시청',
#    'startX': 126.702217,
#    'startY': 37.457614,
#    'endName': '원인재',
#    'endX': 126.687839,
#    'endY': 37.41234,
#    'way': '원인재',
#    'wayCode': 2,
#    'door': '7-2',
#    'startID': 20124,
#    'endID': 20130,
#    'passStopList': {'stations': [{'index': 0,
#       'stationID': 20124,
#       'stationName': '인천시청',
#       'x': '126.70222',
#       'y': '37.457619'},
#      {'index': 1,
#       'stationID': 20125,
#       'stationName': '예술회관',
#       'x': '126.701016',
#       'y': '37.449312'},
#      {'index': 2,
#       'stationID': 20126,
#       'stationName': '인천터미널',
#       'x': '126.699664',
#       'y': '37.441857'},
#      {'index': 3,
#       'stationID': 20127,
#       'stationName': '문학경기장',
#       'x': '126.698344',
#       'y': '37.434959'},
#      {'index': 4,
#       'stationID': 20128,
#       'stationName': '선학',
#       'x': '126.69893',
#       'y': '37.426963'},
#      {'index': 5,
#       'stationID': 20129,
#       'stationName': '신연수',
#       'x': '126.694023',
#       'y': '37.418062'},
#      {'index': 6,
#       'stationID': 20130,
#       'stationName': '원인재',
#       'x': '126.687844',
#       'y': '37.412342'}]}},
#   {'trafficType': 3, 'distance': 0, 'sectionTime': 0},
#   {'trafficType': 1,
#    'distance': 900,
#    'sectionTime': 10,
#    'stationCount': 1,
#    'lane': [{'name': '수도권 수인.분당선', 'subwayCode': 116, 'subwayCityCode': 1000}],
#    'startName': '원인재',
#    'startX': 126.686434,
#    'startY': 37.41319,
#    'endName': '연수',
#    'endX': 126.679034,
#    'endY': 37.417775,
#    'way': '연수',
#    'wayCode': 2,
#    'door': 'null',
#    'startID': 11127,
#    'endID': 11128,
#    'endExitNo': '1',
#    'endExitX': 126.67856864003107,
#    'endExitY': 37.41754866167001,
#    'passStopList': {'stations': [{'index': 0,
#       'stationID': 11127,
#       'stationName': '원인재',
#       'x': '126.686444',
#       'y': '37.413196'},
#      {'index': 1,
#       'stationID': 11128,
#       'stationName': '연수',
#       'x': '126.679039',
#       'y': '37.417776'}]}},
#   {'trafficType': 3, 'distance': 705, 'sectionTime': 11}]}
